# %% [markdown]
# # Finding the Lyapunov Function using Counterexamples Method

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D

from scipy.linalg import solve_continuous_lyapunov
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F

from dreal import *

import timeit 

import tqdm
import copy

# %% [markdown]
# ## Obtaining the Trajectories

# %%
# System matrix
A = np.array([[-2, 1], [-1, -2]])
region = [-1,1]
# Time
t = np.linspace(0, 10, 1000)

# Initial conditions
num_trajectories = 100
x0_values = np.random.uniform(low=0.8, high=1, size=(num_trajectories, 2))

X_data = np.zeros((len(t)*num_trajectories,2))
X_dot_data = np.zeros((len(t)*num_trajectories,2))

# Plotting trajectories
for i in range(num_trajectories):
    x = np.zeros((len(t), 2))
    x_dot = np.zeros((len(t), 2))
    x[0] = x0_values[i]
    for j in range(1, len(t)):
        x_dot[j-1] = np.dot(A, x[j-1])
        x[j] = x[j-1] + x_dot[j-1] * (t[j] - t[j-1])
    X_data[i*len(t):(i+1)*len(t),:] = x
    X_dot_data[i*len(t):(i+1)*len(t),:] = x_dot
    plt.plot(x[:, 0], x[:, 1])

# Plotting the origin
plt.plot(0, 0, 'ro')
plt.text(0.1, 0.1, 'Origin (0, 0)', fontsize=10)

plt.xlabel('x')
plt.ylabel('y')
plt.title('100 Trajectories of the Linear Dynamical System')
plt.grid(True)
plt.axis('equal')
plt.show()

# %%
Q = np.eye(2)
# Defining the Lyapunov Function for the Trajectories
P = solve_continuous_lyapunov(A.T, -Q)
P = torch.tensor(P, dtype=torch.float32)
A = torch.tensor(A, dtype=torch.float32)

# %% [markdown]
# ## Neural Network

# %%
## NN for learning the Lyapunov Function
class Net(torch.nn.Module):
    def __init__(self,n_input,n_hidden,n_output):
        super(Net, self).__init__()
        self.layer1 = torch.nn.Linear(n_input, n_hidden)
        self.layer2 = torch.nn.Linear(n_hidden,n_output)
        # Xavier Initialisation
        nn.init.xavier_uniform_(self.layer1.weight)
        nn.init.xavier_uniform_(self.layer2.weight)
    def forward(self,x):
        sigmoid = torch.nn.Tanh()
        h_1 = sigmoid(self.layer1(x))
        out = sigmoid(self.layer2(h_1))
        return out

# %%
# NN for learning dynamics
class fNet(torch.nn.Module):
    def __init__(self,n_input, n_hidden1,  n_output):
        super().__init__()
        self.layer1 = torch.nn.Linear(n_input, n_hidden1)
        self.layer2 = torch.nn.Linear(n_hidden1,n_output)  
        # Xavier Initialisation
        nn.init.xavier_uniform_(self.layer1.weight)
        nn.init.xavier_uniform_(self.layer2.weight)
    def forward(self,x):
        sigmoid = torch.nn.Tanh()
        h_1 = sigmoid(self.layer1(x))
        out = self.layer2(h_1) 
        return out

# %% [markdown]
# ## Helper Functions

# %%
# Given a dynamical system dx/dt = f(x,u) and candidate Lyapunov function V
# Check the Lyapunov conditions within a domain around the origin (ball_lb ≤ sqrt(∑xᵢ²) ≤ ball_ub). 
# If it return unsat, then there is no state violating the conditions. 
def CheckLyapunov(x, f, V, ball_lb, ball_ub, config, epsilon):    
    ball= Expression(0)
    lie_derivative_of_V = Expression(0)
    
    for i in range(len(x)):
        ball += x[i]*x[i]
        lie_derivative_of_V += f[i]*V.Differentiate(x[i])  
    ball_in_bound = logical_and(ball_lb*ball_lb <= ball, ball <= ball_ub*ball_ub)
    
    # Constraint: x ∈ Ball → (V(c, x) > 0 ∧ Lie derivative of V <= 0)     
    condition = logical_and(logical_imply(ball_in_bound, V >= 0),
                           logical_imply(ball_in_bound, lie_derivative_of_V <= epsilon))
    # Constraint: x^2 < lb → (V(x) = 0)
    V_epsi = 1e-3
    ball_in_bound_internal = logical_and(0 <= ball, ball <= ball_lb*ball_lb)
    condition_y = logical_and(logical_imply(ball_in_bound_internal, V <= V_epsi), condition)
    return CheckSatisfiability(logical_not(condition_y),config)

# Given a candidate Lyapunov function V, check the Lipschitz constant within a domain around the origin (sqrt(∑xᵢ²) ≤ ball_ub). 
# If it return unsat, then there is no state violating the conditions. 
def CheckdVdx(x, V, ball_ub, config, M):        
    ball= Expression(0)
    derivative_of_V = Expression(0)
    
    for i in range(len(x)):
        ball += x[i]*x[i]
        derivative_of_V += V.Differentiate(x[i])*V.Differentiate(x[i])
    ball_in_bound = logical_and(ball <= ball_ub*ball_ub)
    
    # Constraint: x ∈ Ball → partial derivative of V <= M     
    condition = logical_imply(ball_in_bound, derivative_of_V <= M)
    return CheckSatisfiability(logical_not(condition),config)

# Adding Counter-Examples back to sample set
def AddCounterexamples(x,CE,N): 
    c = []
    nearby= []
    for i in range(CE.size()):
        c.append(CE[i].mid())
        lb = CE[i].lb()
        ub = CE[i].ub()
        nearby_ = np.random.uniform(lb,ub,N)
        nearby.append(nearby_)
    for i in range(N):
        n_pt = []
        for j in range(x.shape[1]):
            n_pt.append(nearby[j][i])             
        x = torch.cat((x, torch.tensor([n_pt])), 0)
    return x

# Derivative of activation
def dtanh(s):
    return 1.0 - s**2

# Circle function values
def Tune(x):
    y = []
    for r in range(0,len(x)):
        v = 0 
        for j in range(x.shape[1]):
            v += x[r][j]**2
        f = [torch.sqrt(v)]
        y.append(f)
    y = torch.tensor(y)
    return y

# Loss Function for Warmstarting
def lossfunction_warm(x, y, model_v, model_f):
    # V_candidate = model_v(x)
    y_pred = model_f(x)
    # Circle_Tuning = Tune(x)
    # Circle_Tuning = Circle_Tuning
    loss_fn = nn.MSELoss()  # mean square error
    L1 = loss_fn(y_pred, y)
    #loss = ((Circle_Tuning-V_candidate).pow(2)).mean() + 10 * L1
    loss = L1
    return loss

# %%
################ WARM STARTING #############
# Neural Network Structure
nn_h_f = 50
# Dimensions
nn_x = 2
# Weights for the LOSS
DECAY_MSE = 1
DECAY_LY = 1
DECAY_LYG = 1
# Epochs
n_epochs = 100
lr_warm = 0.005
########################### TRAINING SET ############################################################
X_train, X_test, y_train, y_test = train_test_split(X_data, X_dot_data, train_size=0.2, shuffle=False)
# Convert to 2D PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

########################## Improving V ################################################
'''
For learning the Lyapunov Function and Dynamics Function together
'''
N = 1000            # sample size
D_in = 2           # input dimension
H1 = 10            # hidden dimension
D_out = 1          # output dimension
x = torch.Tensor(N, D_in).uniform_(region[0],region[1])           
x_0 = torch.zeros([1, 2])
'''
For verifying 
'''
x1 = Variable("x1")
x2 = Variable("x2")
vars_ = [x1,x2]
config = Config()
config.use_polytope_in_forall = True
config.use_local_optimization = True
config.precision = 1e-2

learning_rate = 0.0001
# For Verification
beta = -0.02 # initial guess of beta
# Checking candidate V within a ball around the origin (ball_lb ≤ sqrt(∑xᵢ²) ≤ ball_ub)
ball_lb = 1e-4
ball_ub = 2

# parameters for beta
Kf = 3.4599
KF = 5.452
d = 5e-4
loss = 0.0085 # equals alpha above

# %%
# Hold the best model
best_mse = np.inf   # init to infinity
best_weights = None
history = []

# Model
model_f = fNet(nn_x, nn_h_f, nn_x)
model_v = Net(D_in,H1, D_out)

loss_fn = nn.MSELoss()  # mean square error
optimizer_f = torch.optim.Adam(model_f.parameters(), lr = lr_warm)
optimizer_v = torch.optim.Adam(model_v.parameters(), lr = lr_warm)

for epoch in range(n_epochs):
    model_f.train()
    model_v.train()
    # Calculate the loss
    loss = lossfunction_warm(X_train, y_train, model_v, model_f)
    # backward pass
    optimizer_f.zero_grad()
    optimizer_v.zero_grad()
    loss.backward() 
    optimizer_f.step()
    optimizer_v.step()
    #evaluate accuracy at end of each epoch
    model_f.eval()
    model_v.eval()
    y_pred = model_f(X_test)
    mse = lossfunction_warm(X_test, y_test, model_v, model_f)
    mse = float(mse)
    history.append(mse)
    if loss < best_mse:
        best_mse = mse
        best_weights = copy.deepcopy(model_f.state_dict())
    with torch.no_grad():
        torch.cuda.empty_cache()
# restore model and return best accuracy
model_f.load_state_dict(best_weights)
print("MSE: %.4f" % best_mse)
print("RMSE: %.4f" % np.sqrt(best_mse))
plt.plot(history)
plt.show()
model_f.eval()
# Out:
# /home/allemmbinn/miniconda3/lib/python3.11/site-packages/torch/autograd/graph.py:744: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# MSE: 0.0013
# RMSE: 0.0361
# fNet(
#   (layer1): Linear(in_features=2, out_features=50, bias=True)
#   (layer2): Linear(in_features=50, out_features=2, bias=True)
# )

# %% [markdown]
# ## Taking Train Dataset Whole

# %%
out_iters = 0
valid = False
while out_iters < 2 and not valid: 
    start = timeit.default_timer()
    model_v = Net(D_in,H1, D_out)
    L = []
    i = 0 
    t = 0
    max_iters = 5000 # increase number of epoches if cannot find a valid LF
    optimizer_v = torch.optim.Adam(model_v.parameters(), lr=learning_rate)

    while i < max_iters and not valid: 
        # Calculate the loss
        x = x.float()
        x = x
        # Value of Lyapunov Model
        V_candidate = model_v(x)
        X0 = model_v(x_0)
        # Value of Function Model
        f = model_f(x)
        Circle_Tuning = Tune(x)
        Circle_Tuning = Circle_Tuning
        # Compute lie derivative of V : L_V = ∑∂V/∂xᵢ*fᵢ
        L_V = torch.diagonal(torch.mm(torch.mm(torch.mm(dtanh(V_candidate),model_v.layer2.weight)\
                            *dtanh(torch.tanh(torch.mm(x,model_v.layer1.weight.t())+model_v.layer1.bias)),model_v.layer1.weight),f.t()),0)
        
        dVdx = torch.mm(torch.mm(dtanh(V_candidate),model_v.layer2.weight)\
                            *dtanh(torch.tanh(torch.mm(x,model_v.layer1.weight.t())+model_v.layer1.bias)),model_v.layer1.weight)
                
        # MSE Loss
        L1 = loss_fn(model_f(X_train),y_train)
                
        # Needs to be tuned
        Lyapunov_risk = (F.relu(-V_candidate)+ 1.2*F.relu(L_V+0.2)).mean() +((Circle_Tuning-V_candidate).pow(2)).mean() + 5*(X0).pow(2) + 0.01*torch.norm(dVdx) + 0.5 * L1
 
        L.append(Lyapunov_risk.item())
        optimizer_v.zero_grad()
        optimizer_f.zero_grad()
        Lyapunov_risk.backward()
        optimizer_v.step() 
        optimizer_f.step() 

        print(f"{i}) Lyapunov Risk = {Lyapunov_risk.item()}, MSE = {L1}, V_0_loss = {(X0).pow(2).float()}, V_pos_loss = {F.relu(-V_candidate).mean()}, Lv_loss = {F.relu(L_V).mean()}, Circular Tuning Loss = {((Circle_Tuning-V_candidate).pow(2)).mean()}")
        # Finding the values for the new model function
        f_w1 = model_f.layer1.weight.data.cpu().numpy()
        f_w2 = model_f.layer2.weight.data.cpu().numpy()
        f_b1 = model_f.layer1.bias.data.cpu().numpy()
        f_b2 = model_f.layer2.bias.data.cpu().numpy()

        f_h1 = []
        f_z1 = np.dot(vars_,f_w1.T)+f_b1
        for n in range(len(f_z1)):
            f_h1.append(tanh(f_z1[n]))
        f_learn = np.dot(f_h1,f_w2.T)+f_b2
        # save the weights and biases 
        w1 = model_v.layer1.weight.data.cpu().numpy()
        w2 = model_v.layer2.weight.data.cpu().numpy()
        b1 = model_v.layer1.bias.data.cpu().numpy()
        b2 = model_v.layer2.bias.data.cpu().numpy()
        
        # Falsification with SMT solver
        if i % 10 == 0:
                    
            # Candidate V
            z1 = np.dot(vars_,w1.T)+b1
        
            a1 = []
            for j in range(0,len(z1)):
                a1.append(tanh(z1[j]))
            z2 = np.dot(a1,w2.T)+b2
            V_learn = tanh(z2.item(0))
        
            print('===========Verifying==========')        
            start_ = timeit.default_timer() 
            beta = -np.maximum(beta, -0.02) # in case beta is too negative and cannot return any results
            result= CheckLyapunov(vars_, f_learn, V_learn, ball_lb, ball_ub, config, beta) # SMT solver
            stop_ = timeit.default_timer() 
        
            if (result): 
                    print("Not a Lyapunov function. Found counterexample: ")
                    print(result)
                    x = x.to('cpu')
                    x = AddCounterexamples(x,result,10)
            else:  
                    # # calculate norm of dVdx with the SMT solver
                    # M = 0.05 # lower bound of M
                    # dvdx_bound = np.sqrt(M)
                    # violation = CheckdVdx(vars_, V_learn, ball_ub, config, M) 
                    # while violation:
                    #     violation = CheckdVdx(vars_, V_learn, ball_ub, config, M)
                    #     if not violation:
                    #         dvdx_bound = np.sqrt(M)
                    #         print(dvdx_bound, "is the norm of dVdx")
                    #     M += 0.001
                    # beta = -dvdx_bound*((Kf+KF)*d+loss) # update beta 
                    # print("Satisfies with a non-strict condition")
                    # result_strict= CheckLyapunov(vars_, f_learn, V_learn, ball_lb, ball_ub, config, beta) # SMT solver
                    # beta = beta.detach().numpy()
                    # if not result_strict:
                    #     valid = True
                    #     print("Satisfy conditions with beta = ", beta)
                    #     print(V_learn, " is a Lyapunov function.")
                    valid = True
                    print("Satisfy conditions")
                    print(V_learn, " is a Lyapunov function.")
            t += (stop_ - start_)
            print('==============================') 
        i += 1

    stop = timeit.default_timer()
    
    np.savetxt("w1_vdp.txt", model_v.layer1.weight.data.cpu(), fmt="%s")
    np.savetxt("w2_vdp.txt", model_v.layer2.weight.data.cpu(), fmt="%s")
    np.savetxt("b1_vdp.txt", model_v.layer1.bias.data.cpu(), fmt="%s")
    np.savetxt("b2_vdp.txt", model_v.layer2.bias.data.cpu(), fmt="%s")

    print('\n')
    print("Total time: ", stop - start)
    print("Verified time: ", t)
    
    out_iters+=1
# Out:
# 0) Lyapunov Risk = 3.112523317337036, MSE = 0.011792123317718506, V_0_loss = tensor([[0.2820]], grad_fn=<PowBackward0>), V_pos_loss = 0.5135228633880615, Lv_loss = 0.028959259390830994, Circular Tuning Loss = 0.7879743576049805
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 1) Lyapunov Risk = 3.033449649810791, MSE = 0.1042470708489418, V_0_loss = tensor([[0.2814]], grad_fn=<PowBackward0>), V_pos_loss = 0.5130901336669922, Lv_loss = 0.01919122226536274, Circular Tuning Loss = 0.7853219509124756
# 2) Lyapunov Risk = 3.1325979232788086, MSE = 0.41565850377082825, V_0_loss = tensor([[0.2809]], grad_fn=<PowBackward0>), V_pos_loss = 0.5125911831855774, Lv_loss = 0.01064829807728529, Circular Tuning Loss = 0.7845483422279358
# 3) Lyapunov Risk = 3.0718984603881836, MSE = 0.2988196909427643, V_0_loss = tensor([[0.2803]], grad_fn=<PowBackward0>), V_pos_loss = 0.5120928287506104, Lv_loss = 0.011118528433144093, Circular Tuning Loss = 0.7837763428688049
# 4) Lyapunov Risk = 3.0309767723083496, MSE = 0.08472967892885208, V_0_loss = tensor([[0.2798]], grad_fn=<PowBackward0>), V_pos_loss = 0.5115944743156433, Lv_loss = 0.01596466638147831, Circular Tuning Loss = 0.7830051779747009
# 5) Lyapunov Risk = 3.0605692863464355, MSE = 0.014972983859479427, V_0_loss = tensor([[0.2792]], grad_fn=<PowBackward0>), V_pos_loss = 0.5110952258110046, Lv_loss = 0.01885901764035225, Circular Tuning Loss = 0.7822326421737671
# 6) Lyapunov Risk = 3.0615899562835693, MSE = 0.014929168857634068, V_0_loss = tensor([[0.2787]], grad_fn=<PowBackward0>), V_pos_loss = 0.5105959177017212, Lv_loss = 0.01683070883154869, Circular Tuning Loss = 0.7814607620239258
# 7) Lyapunov Risk = 3.0344481468200684, MSE = 0.062246501445770264, V_0_loss = tensor([[0.2781]], grad_fn=<PowBackward0>), V_pos_loss = 0.5100964307785034, Lv_loss = 0.01113585289567709, Circular Tuning Loss = 0.7806891202926636
# 8) Lyapunov Risk = 3.00700306892395, MSE = 0.15526990592479706, V_0_loss = tensor([[0.2776]], grad_fn=<PowBackward0>), V_pos_loss = 0.5095965266227722, Lv_loss = 0.005519343540072441, Circular Tuning Loss = 0.7799174189567566
# 9) Lyapunov Risk = 3.0152158737182617, MSE = 0.26558205485343933, V_0_loss = tensor([[0.2770]], grad_fn=<PowBackward0>), V_pos_loss = 0.5090957880020142, Lv_loss = 0.002671844558790326, Circular Tuning Loss = 0.7791448831558228
# 10) Lyapunov Risk = 2.993213176727295, MSE = 0.23283489048480988, V_0_loss = tensor([[0.2765]], grad_fn=<PowBackward0>), V_pos_loss = 0.5085949897766113, Lv_loss = 0.0019176958594471216, Circular Tuning Loss = 0.7783728837966919
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 11) Lyapunov Risk = 2.989396095275879, MSE = 0.14520485699176788, V_0_loss = tensor([[0.2759]], grad_fn=<PowBackward0>), V_pos_loss = 0.5081579089164734, Lv_loss = 0.001880869036540389, Circular Tuning Loss = 0.7757435441017151
# 12) Lyapunov Risk = 3.0040509700775146, MSE = 0.10999128222465515, V_0_loss = tensor([[0.2754]], grad_fn=<PowBackward0>), V_pos_loss = 0.5076555609703064, Lv_loss = 0.0016859538154676557, Circular Tuning Loss = 0.7749711275100708
# 13) Lyapunov Risk = 2.9895236492156982, MSE = 0.08002053201198578, V_0_loss = tensor([[0.2748]], grad_fn=<PowBackward0>), V_pos_loss = 0.5071525573730469, Lv_loss = 0.001195812365040183, Circular Tuning Loss = 0.7741978764533997
# 14) Lyapunov Risk = 2.964505672454834, MSE = 0.08474612236022949, V_0_loss = tensor([[0.2743]], grad_fn=<PowBackward0>), V_pos_loss = 0.5066488981246948, Lv_loss = 0.000702284334693104, Circular Tuning Loss = 0.7734243273735046
# 15) Lyapunov Risk = 2.9555225372314453, MSE = 0.15424074232578278, V_0_loss = tensor([[0.2738]], grad_fn=<PowBackward0>), V_pos_loss = 0.5061444044113159, Lv_loss = 0.00046826372272334993, Circular Tuning Loss = 0.7726500034332275
# 16) Lyapunov Risk = 2.966038465499878, MSE = 0.25088241696357727, V_0_loss = tensor([[0.2732]], grad_fn=<PowBackward0>), V_pos_loss = 0.5056391954421997, Lv_loss = 0.00032295106211677194, Circular Tuning Loss = 0.7718748450279236
# 17) Lyapunov Risk = 2.9487195014953613, MSE = 0.208382710814476, V_0_loss = tensor([[0.2727]], grad_fn=<PowBackward0>), V_pos_loss = 0.5051343441009521, Lv_loss = 0.00030150747625157237, Circular Tuning Loss = 0.7711008191108704
# 18) Lyapunov Risk = 2.935429811477661, MSE = 0.15843872725963593, V_0_loss = tensor([[0.2721]], grad_fn=<PowBackward0>), V_pos_loss = 0.5046284198760986, Lv_loss = 0.0004890681011602283, Circular Tuning Loss = 0.7703257203102112
# 19) Lyapunov Risk = 2.930661201477051, MSE = 0.13781249523162842, V_0_loss = tensor([[0.2716]], grad_fn=<PowBackward0>), V_pos_loss = 0.5041216611862183, Lv_loss = 0.0007633095374330878, Circular Tuning Loss = 0.7695497870445251
# 20) Lyapunov Risk = 2.9309542179107666, MSE = 0.1518491506576538, V_0_loss = tensor([[0.2710]], grad_fn=<PowBackward0>), V_pos_loss = 0.503614068031311, Lv_loss = 0.0009340451215393841, Circular Tuning Loss = 0.768773078918457
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 21) Lyapunov Risk = 2.9253990650177, MSE = 0.18364626169204712, V_0_loss = tensor([[0.2705]], grad_fn=<PowBackward0>), V_pos_loss = 0.5031681656837463, Lv_loss = 0.000838176638353616, Circular Tuning Loss = 0.7661599516868591
# 22) Lyapunov Risk = 2.925943613052368, MSE = 0.22005434334278107, V_0_loss = tensor([[0.2699]], grad_fn=<PowBackward0>), V_pos_loss = 0.5026587247848511, Lv_loss = 0.0005910437321290374, Circular Tuning Loss = 0.7653822302818298
# 23) Lyapunov Risk = 2.908740997314453, MSE = 0.17290754616260529, V_0_loss = tensor([[0.2694]], grad_fn=<PowBackward0>), V_pos_loss = 0.5021502375602722, Lv_loss = 0.0006894490798003972, Circular Tuning Loss = 0.7646061778068542
# 24) Lyapunov Risk = 2.9036197662353516, MSE = 0.14853435754776, V_0_loss = tensor([[0.2688]], grad_fn=<PowBackward0>), V_pos_loss = 0.5016406774520874, Lv_loss = 0.0006342657143250108, Circular Tuning Loss = 0.7638293504714966
# 25) Lyapunov Risk = 2.9006590843200684, MSE = 0.14939166605472565, V_0_loss = tensor([[0.2683]], grad_fn=<PowBackward0>), V_pos_loss = 0.5011304616928101, Lv_loss = 0.00045027685700915754, Circular Tuning Loss = 0.7630520462989807
# 26) Lyapunov Risk = 2.897170066833496, MSE = 0.16471560299396515, V_0_loss = tensor([[0.2677]], grad_fn=<PowBackward0>), V_pos_loss = 0.5006198287010193, Lv_loss = 0.00020729345851577818, Circular Tuning Loss = 0.7622746229171753
# 27) Lyapunov Risk = 2.891080379486084, MSE = 0.18138915300369263, V_0_loss = tensor([[0.2672]], grad_fn=<PowBackward0>), V_pos_loss = 0.5001086592674255, Lv_loss = 7.555652700830251e-05, Circular Tuning Loss = 0.7614970207214355
# 28) Lyapunov Risk = 2.886049747467041, MSE = 0.1936047077178955, V_0_loss = tensor([[0.2666]], grad_fn=<PowBackward0>), V_pos_loss = 0.49959686398506165, Lv_loss = 3.612796717789024e-05, Circular Tuning Loss = 0.7607189416885376
# 29) Lyapunov Risk = 2.880038261413574, MSE = 0.13103589415550232, V_0_loss = tensor([[0.2661]], grad_fn=<PowBackward0>), V_pos_loss = 0.49908605217933655, Lv_loss = 3.237782948417589e-05, Circular Tuning Loss = 0.7599429488182068
# 30) Lyapunov Risk = 2.882582664489746, MSE = 0.10321126878261566, V_0_loss = tensor([[0.2656]], grad_fn=<PowBackward0>), V_pos_loss = 0.49857452511787415, Lv_loss = 2.8430215024854988e-05, Circular Tuning Loss = 0.7591663599014282
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 31) Lyapunov Risk = 2.8793623447418213, MSE = 0.10146339237689972, V_0_loss = tensor([[0.2650]], grad_fn=<PowBackward0>), V_pos_loss = 0.49812424182891846, Lv_loss = 2.2499551050714217e-05, Circular Tuning Loss = 0.7565760016441345
# 32) Lyapunov Risk = 2.8699827194213867, MSE = 0.1178264394402504, V_0_loss = tensor([[0.2645]], grad_fn=<PowBackward0>), V_pos_loss = 0.4976119101047516, Lv_loss = 1.722643537505064e-05, Circular Tuning Loss = 0.7557999491691589
# 33) Lyapunov Risk = 2.859464645385742, MSE = 0.15259580314159393, V_0_loss = tensor([[0.2639]], grad_fn=<PowBackward0>), V_pos_loss = 0.4970989525318146, Lv_loss = 1.1916128642042167e-05, Circular Tuning Loss = 0.7550235390663147
# 34) Lyapunov Risk = 2.8632354736328125, MSE = 0.20247647166252136, V_0_loss = tensor([[0.2634]], grad_fn=<PowBackward0>), V_pos_loss = 0.4965851604938507, Lv_loss = 7.73839474277338e-06, Circular Tuning Loss = 0.7542463541030884
# 35) Lyapunov Risk = 2.850212574005127, MSE = 0.16849768161773682, V_0_loss = tensor([[0.2628]], grad_fn=<PowBackward0>), V_pos_loss = 0.4960726201534271, Lv_loss = 6.179253887239611e-06, Circular Tuning Loss = 0.7534712553024292
# 36) Lyapunov Risk = 2.8472681045532227, MSE = 0.14273479580879211, V_0_loss = tensor([[0.2623]], grad_fn=<PowBackward0>), V_pos_loss = 0.4955591857433319, Lv_loss = 3.5935972846345976e-06, Circular Tuning Loss = 0.7526955008506775
# 37) Lyapunov Risk = 2.843660831451416, MSE = 0.128579244017601, V_0_loss = tensor([[0.2617]], grad_fn=<PowBackward0>), V_pos_loss = 0.49504515528678894, Lv_loss = 4.18857609929546e-07, Circular Tuning Loss = 0.7519192099571228
# 38) Lyapunov Risk = 2.8385002613067627, MSE = 0.1277226358652115, V_0_loss = tensor([[0.2612]], grad_fn=<PowBackward0>), V_pos_loss = 0.494530588388443, Lv_loss = 0.0, Circular Tuning Loss = 0.751142680644989
# 39) Lyapunov Risk = 2.832284688949585, MSE = 0.14032863080501556, V_0_loss = tensor([[0.2607]], grad_fn=<PowBackward0>), V_pos_loss = 0.494015634059906, Lv_loss = 0.0, Circular Tuning Loss = 0.7503659129142761
# 40) Lyapunov Risk = 2.826404094696045, MSE = 0.16394038498401642, V_0_loss = tensor([[0.2601]], grad_fn=<PowBackward0>), V_pos_loss = 0.49350011348724365, Lv_loss = 0.0, Circular Tuning Loss = 0.7495887279510498
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 41) Lyapunov Risk = 2.8278822898864746, MSE = 0.19254660606384277, V_0_loss = tensor([[0.2596]], grad_fn=<PowBackward0>), V_pos_loss = 0.4930442273616791, Lv_loss = 0.0, Circular Tuning Loss = 0.7470189332962036
# 42) Lyapunov Risk = 2.8176639080047607, MSE = 0.146017387509346, V_0_loss = tensor([[0.2590]], grad_fn=<PowBackward0>), V_pos_loss = 0.49252933263778687, Lv_loss = 0.0, Circular Tuning Loss = 0.7462445497512817
# 43) Lyapunov Risk = 2.8164892196655273, MSE = 0.1188771203160286, V_0_loss = tensor([[0.2585]], grad_fn=<PowBackward0>), V_pos_loss = 0.4920135736465454, Lv_loss = 2.2893393634149106e-06, Circular Tuning Loss = 0.745469331741333
# 44) Lyapunov Risk = 2.8127834796905518, MSE = 0.11213526874780655, V_0_loss = tensor([[0.2579]], grad_fn=<PowBackward0>), V_pos_loss = 0.4914974272251129, Lv_loss = 5.3919256970402785e-06, Circular Tuning Loss = 0.7446939945220947
# 45) Lyapunov Risk = 2.806180715560913, MSE = 0.12526310980319977, V_0_loss = tensor([[0.2574]], grad_fn=<PowBackward0>), V_pos_loss = 0.4909808933734894, Lv_loss = 0.0, Circular Tuning Loss = 0.7439184784889221
# 46) Lyapunov Risk = 2.799715995788574, MSE = 0.15486890077590942, V_0_loss = tensor([[0.2569]], grad_fn=<PowBackward0>), V_pos_loss = 0.49046388268470764, Lv_loss = 0.0, Circular Tuning Loss = 0.7431430220603943
# 47) Lyapunov Risk = 2.803255319595337, MSE = 0.1919659972190857, V_0_loss = tensor([[0.2563]], grad_fn=<PowBackward0>), V_pos_loss = 0.48994624614715576, Lv_loss = 0.0, Circular Tuning Loss = 0.7423670887947083
# 48) Lyapunov Risk = 2.7915148735046387, MSE = 0.14988508820533752, V_0_loss = tensor([[0.2558]], grad_fn=<PowBackward0>), V_pos_loss = 0.48942992091178894, Lv_loss = 0.0, Circular Tuning Loss = 0.7415937185287476
# 49) Lyapunov Risk = 2.7894537448883057, MSE = 0.12371308356523514, V_0_loss = tensor([[0.2552]], grad_fn=<PowBackward0>), V_pos_loss = 0.48891279101371765, Lv_loss = 1.4636882497143233e-06, Circular Tuning Loss = 0.7408196926116943
# 50) Lyapunov Risk = 2.7863757610321045, MSE = 0.11644699424505234, V_0_loss = tensor([[0.2547]], grad_fn=<PowBackward0>), V_pos_loss = 0.48839518427848816, Lv_loss = 8.57798022479983e-06, Circular Tuning Loss = 0.740045428276062
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 51) Lyapunov Risk = 2.7794930934906006, MSE = 0.12644833326339722, V_0_loss = tensor([[0.2541]], grad_fn=<PowBackward0>), V_pos_loss = 0.4879363477230072, Lv_loss = 4.1930934457923286e-06, Circular Tuning Loss = 0.7375006079673767
# 52) Lyapunov Risk = 2.773042917251587, MSE = 0.1504504382610321, V_0_loss = tensor([[0.2536]], grad_fn=<PowBackward0>), V_pos_loss = 0.48741766810417175, Lv_loss = 0.0, Circular Tuning Loss = 0.736726701259613
# 53) Lyapunov Risk = 2.7739596366882324, MSE = 0.18321464955806732, V_0_loss = tensor([[0.2531]], grad_fn=<PowBackward0>), V_pos_loss = 0.48689815402030945, Lv_loss = 0.0, Circular Tuning Loss = 0.7359521389007568
# 54) Lyapunov Risk = 2.765000343322754, MSE = 0.14510014653205872, V_0_loss = tensor([[0.2525]], grad_fn=<PowBackward0>), V_pos_loss = 0.48638004064559937, Lv_loss = 9.167590064862452e-07, Circular Tuning Loss = 0.7351800799369812
# 55) Lyapunov Risk = 2.7630629539489746, MSE = 0.12277441471815109, V_0_loss = tensor([[0.2520]], grad_fn=<PowBackward0>), V_pos_loss = 0.4858610928058624, Lv_loss = 1.5569874449283816e-05, Circular Tuning Loss = 0.734407365322113
# 56) Lyapunov Risk = 2.7596828937530518, MSE = 0.11702194809913635, V_0_loss = tensor([[0.2514]], grad_fn=<PowBackward0>), V_pos_loss = 0.4853415787220001, Lv_loss = 2.69383945123991e-05, Circular Tuning Loss = 0.7336342930793762
# 57) Lyapunov Risk = 2.754434108734131, MSE = 0.12632966041564941, V_0_loss = tensor([[0.2509]], grad_fn=<PowBackward0>), V_pos_loss = 0.48482152819633484, Lv_loss = 1.957875610969495e-05, Circular Tuning Loss = 0.7328610420227051
# 58) Lyapunov Risk = 2.748626470565796, MSE = 0.14782145619392395, V_0_loss = tensor([[0.2504]], grad_fn=<PowBackward0>), V_pos_loss = 0.48430100083351135, Lv_loss = 6.780880084988894e-06, Circular Tuning Loss = 0.7320874929428101
# 59) Lyapunov Risk = 2.7475805282592773, MSE = 0.17630107700824738, V_0_loss = tensor([[0.2498]], grad_fn=<PowBackward0>), V_pos_loss = 0.48377975821495056, Lv_loss = 3.854528642932564e-07, Circular Tuning Loss = 0.7313134074211121
# 60) Lyapunov Risk = 2.7410764694213867, MSE = 0.13614977896213531, V_0_loss = tensor([[0.2493]], grad_fn=<PowBackward0>), V_pos_loss = 0.48325997591018677, Lv_loss = 3.142578134429641e-05, Circular Tuning Loss = 0.7305421233177185
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 61) Lyapunov Risk = 2.7383391857147217, MSE = 0.11396437883377075, V_0_loss = tensor([[0.2487]], grad_fn=<PowBackward0>), V_pos_loss = 0.4827978014945984, Lv_loss = 9.603347280062735e-05, Circular Tuning Loss = 0.7280213236808777
# 62) Lyapunov Risk = 2.7351088523864746, MSE = 0.1097797155380249, V_0_loss = tensor([[0.2482]], grad_fn=<PowBackward0>), V_pos_loss = 0.4822770357131958, Lv_loss = 0.00012664988753385842, Circular Tuning Loss = 0.7272500991821289
# 63) Lyapunov Risk = 2.729189395904541, MSE = 0.12165571004152298, V_0_loss = tensor([[0.2477]], grad_fn=<PowBackward0>), V_pos_loss = 0.4817558526992798, Lv_loss = 9.566252992954105e-05, Circular Tuning Loss = 0.7264787554740906
# 64) Lyapunov Risk = 2.7225608825683594, MSE = 0.14720849692821503, V_0_loss = tensor([[0.2471]], grad_fn=<PowBackward0>), V_pos_loss = 0.48123419284820557, Lv_loss = 4.239184636389837e-05, Circular Tuning Loss = 0.7257071137428284
# 65) Lyapunov Risk = 2.72538161277771, MSE = 0.18144528567790985, V_0_loss = tensor([[0.2466]], grad_fn=<PowBackward0>), V_pos_loss = 0.48071181774139404, Lv_loss = 9.27929886529455e-06, Circular Tuning Loss = 0.7249349355697632
# 66) Lyapunov Risk = 2.7144970893859863, MSE = 0.14635883271694183, V_0_loss = tensor([[0.2460]], grad_fn=<PowBackward0>), V_pos_loss = 0.4801909327507019, Lv_loss = 4.977983917342499e-05, Circular Tuning Loss = 0.724165678024292
# 67) Lyapunov Risk = 2.7123947143554688, MSE = 0.1252259612083435, V_0_loss = tensor([[0.2455]], grad_fn=<PowBackward0>), V_pos_loss = 0.47966906428337097, Lv_loss = 0.00010427224333398044, Circular Tuning Loss = 0.7233954668045044
# 68) Lyapunov Risk = 2.7091376781463623, MSE = 0.11925500631332397, V_0_loss = tensor([[0.2450]], grad_fn=<PowBackward0>), V_pos_loss = 0.479146808385849, Lv_loss = 0.000130717788124457, Circular Tuning Loss = 0.7226248979568481
# 69) Lyapunov Risk = 2.7040698528289795, MSE = 0.12734900414943695, V_0_loss = tensor([[0.2444]], grad_fn=<PowBackward0>), V_pos_loss = 0.4786239266395569, Lv_loss = 0.00010741212463472039, Circular Tuning Loss = 0.7218543887138367
# 70) Lyapunov Risk = 2.6982977390289307, MSE = 0.1472589075565338, V_0_loss = tensor([[0.2439]], grad_fn=<PowBackward0>), V_pos_loss = 0.4781005084514618, Lv_loss = 6.343491259030998e-05, Circular Tuning Loss = 0.7210834622383118
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 71) Lyapunov Risk = 2.697434663772583, MSE = 0.17456220090389252, V_0_loss = tensor([[0.2434]], grad_fn=<PowBackward0>), V_pos_loss = 0.47763344645500183, Lv_loss = 2.876395774364937e-05, Circular Tuning Loss = 0.7185841202735901
# 72) Lyapunov Risk = 2.6895973682403564, MSE = 0.1371995359659195, V_0_loss = tensor([[0.2428]], grad_fn=<PowBackward0>), V_pos_loss = 0.4771108329296112, Lv_loss = 9.894595859805122e-05, Circular Tuning Loss = 0.7178165316581726
# 73) Lyapunov Risk = 2.6881070137023926, MSE = 0.11682679504156113, V_0_loss = tensor([[0.2423]], grad_fn=<PowBackward0>), V_pos_loss = 0.4765874743461609, Lv_loss = 0.00018097629072144628, Circular Tuning Loss = 0.7170482873916626
# 74) Lyapunov Risk = 2.68468976020813, MSE = 0.11332272738218307, V_0_loss = tensor([[0.2418]], grad_fn=<PowBackward0>), V_pos_loss = 0.47606360912323, Lv_loss = 0.00020102487178519368, Circular Tuning Loss = 0.7162798047065735
# 75) Lyapunov Risk = 2.6789042949676514, MSE = 0.12506455183029175, V_0_loss = tensor([[0.2412]], grad_fn=<PowBackward0>), V_pos_loss = 0.4755394160747528, Lv_loss = 0.0001508757850388065, Circular Tuning Loss = 0.7155112624168396
# 76) Lyapunov Risk = 2.672616720199585, MSE = 0.14962239563465118, V_0_loss = tensor([[0.2407]], grad_fn=<PowBackward0>), V_pos_loss = 0.4750145375728607, Lv_loss = 7.698474655626342e-05, Circular Tuning Loss = 0.7147424817085266
# 77) Lyapunov Risk = 2.6773428916931152, MSE = 0.18197846412658691, V_0_loss = tensor([[0.2402]], grad_fn=<PowBackward0>), V_pos_loss = 0.4744890332221985, Lv_loss = 3.073109110118821e-05, Circular Tuning Loss = 0.7139730453491211
# 78) Lyapunov Risk = 2.6647820472717285, MSE = 0.146958589553833, V_0_loss = tensor([[0.2396]], grad_fn=<PowBackward0>), V_pos_loss = 0.47396528720855713, Lv_loss = 8.934181096265092e-05, Circular Tuning Loss = 0.7132067680358887
# 79) Lyapunov Risk = 2.6627707481384277, MSE = 0.12595856189727783, V_0_loss = tensor([[0.2391]], grad_fn=<PowBackward0>), V_pos_loss = 0.4734407365322113, Lv_loss = 0.0001666505850153044, Circular Tuning Loss = 0.7124395966529846
# 80) Lyapunov Risk = 2.659590482711792, MSE = 0.11997683346271515, V_0_loss = tensor([[0.2386]], grad_fn=<PowBackward0>), V_pos_loss = 0.4729156792163849, Lv_loss = 0.00020098956883884966, Circular Tuning Loss = 0.7116721868515015
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 81) Lyapunov Risk = 2.6531970500946045, MSE = 0.12795910239219666, V_0_loss = tensor([[0.2380]], grad_fn=<PowBackward0>), V_pos_loss = 0.4724462330341339, Lv_loss = 0.00017522148846182972, Circular Tuning Loss = 0.7091977000236511
# 82) Lyapunov Risk = 2.6473493576049805, MSE = 0.1478022038936615, V_0_loss = tensor([[0.2375]], grad_fn=<PowBackward0>), V_pos_loss = 0.47192034125328064, Lv_loss = 0.00011410882871132344, Circular Tuning Loss = 0.7084307074546814
# 83) Lyapunov Risk = 2.649672031402588, MSE = 0.1754482239484787, V_0_loss = tensor([[0.2370]], grad_fn=<PowBackward0>), V_pos_loss = 0.47139373421669006, Lv_loss = 6.537730223499238e-05, Circular Tuning Loss = 0.7076632380485535
# 84) Lyapunov Risk = 2.6399426460266113, MSE = 0.14014430344104767, V_0_loss = tensor([[0.2364]], grad_fn=<PowBackward0>), V_pos_loss = 0.47086864709854126, Lv_loss = 0.000159099479787983, Circular Tuning Loss = 0.7068987488746643
# 85) Lyapunov Risk = 2.638214349746704, MSE = 0.12055909633636475, V_0_loss = tensor([[0.2359]], grad_fn=<PowBackward0>), V_pos_loss = 0.4703429043292999, Lv_loss = 0.00025337128317914903, Circular Tuning Loss = 0.7061336636543274
# 86) Lyapunov Risk = 2.634805917739868, MSE = 0.11671723425388336, V_0_loss = tensor([[0.2354]], grad_fn=<PowBackward0>), V_pos_loss = 0.46981680393218994, Lv_loss = 0.0002861678949557245, Circular Tuning Loss = 0.7053683400154114
# 87) Lyapunov Risk = 2.6293368339538574, MSE = 0.12721143662929535, V_0_loss = tensor([[0.2348]], grad_fn=<PowBackward0>), V_pos_loss = 0.4692903161048889, Lv_loss = 0.00023072857584338635, Circular Tuning Loss = 0.7046030759811401
# 88) Lyapunov Risk = 2.6233224868774414, MSE = 0.14969579875469208, V_0_loss = tensor([[0.2343]], grad_fn=<PowBackward0>), V_pos_loss = 0.46876341104507446, Lv_loss = 0.0001473415904911235, Circular Tuning Loss = 0.7038373947143555
# 89) Lyapunov Risk = 2.6282289028167725, MSE = 0.1795426905155182, V_0_loss = tensor([[0.2338]], grad_fn=<PowBackward0>), V_pos_loss = 0.4682360291481018, Lv_loss = 8.366086694877595e-05, Circular Tuning Loss = 0.7030712962150574
# 90) Lyapunov Risk = 2.6156654357910156, MSE = 0.14504608511924744, V_0_loss = tensor([[0.2332]], grad_fn=<PowBackward0>), V_pos_loss = 0.4677102565765381, Lv_loss = 0.00017907073197420686, Circular Tuning Loss = 0.7023082971572876
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 91) Lyapunov Risk = 2.6124322414398193, MSE = 0.12484271079301834, V_0_loss = tensor([[0.2327]], grad_fn=<PowBackward0>), V_pos_loss = 0.46723824739456177, Lv_loss = 0.00027831917395815253, Circular Tuning Loss = 0.6998583674430847
# 92) Lyapunov Risk = 2.6092050075531006, MSE = 0.11969458311796188, V_0_loss = tensor([[0.2322]], grad_fn=<PowBackward0>), V_pos_loss = 0.46671104431152344, Lv_loss = 0.0003262822865508497, Circular Tuning Loss = 0.6990952491760254
# 93) Lyapunov Risk = 2.6040587425231934, MSE = 0.12826381623744965, V_0_loss = tensor([[0.2317]], grad_fn=<PowBackward0>), V_pos_loss = 0.4661833643913269, Lv_loss = 0.00028067646780982614, Circular Tuning Loss = 0.6983320116996765
# 94) Lyapunov Risk = 2.59818172454834, MSE = 0.148565873503685, V_0_loss = tensor([[0.2311]], grad_fn=<PowBackward0>), V_pos_loss = 0.465655118227005, Lv_loss = 0.00020177525584585965, Circular Tuning Loss = 0.697568416595459
# 95) Lyapunov Risk = 2.602315664291382, MSE = 0.17654481530189514, V_0_loss = tensor([[0.2306]], grad_fn=<PowBackward0>), V_pos_loss = 0.4651261866092682, Lv_loss = 0.0001257933326996863, Circular Tuning Loss = 0.6968045234680176
# 96) Lyapunov Risk = 2.5906858444213867, MSE = 0.14266306161880493, V_0_loss = tensor([[0.2301]], grad_fn=<PowBackward0>), V_pos_loss = 0.46459895372390747, Lv_loss = 0.0002449011954013258, Circular Tuning Loss = 0.6960436701774597
# 97) Lyapunov Risk = 2.588820457458496, MSE = 0.12338157743215561, V_0_loss = tensor([[0.2295]], grad_fn=<PowBackward0>), V_pos_loss = 0.4640708863735199, Lv_loss = 0.0003695984196383506, Circular Tuning Loss = 0.6952821612358093
# 98) Lyapunov Risk = 2.5854833126068115, MSE = 0.11907058954238892, V_0_loss = tensor([[0.2290]], grad_fn=<PowBackward0>), V_pos_loss = 0.4635423719882965, Lv_loss = 0.00041833004797808826, Circular Tuning Loss = 0.6945204734802246
# 99) Lyapunov Risk = 2.580244541168213, MSE = 0.1284063756465912, V_0_loss = tensor([[0.2285]], grad_fn=<PowBackward0>), V_pos_loss = 0.46301349997520447, Lv_loss = 0.00035390668199397624, Circular Tuning Loss = 0.6937585473060608
# 100) Lyapunov Risk = 2.5743772983551025, MSE = 0.14925266802310944, V_0_loss = tensor([[0.2280]], grad_fn=<PowBackward0>), V_pos_loss = 0.46248406171798706, Lv_loss = 0.0002503831929061562, Circular Tuning Loss = 0.6929965019226074
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 101) Lyapunov Risk = 2.5782835483551025, MSE = 0.17749980092048645, V_0_loss = tensor([[0.2274]], grad_fn=<PowBackward0>), V_pos_loss = 0.46200764179229736, Lv_loss = 0.0001639455440454185, Circular Tuning Loss = 0.6905683875083923
# 102) Lyapunov Risk = 2.5655109882354736, MSE = 0.1441308557987213, V_0_loss = tensor([[0.2269]], grad_fn=<PowBackward0>), V_pos_loss = 0.4614795446395874, Lv_loss = 0.0002914614451583475, Circular Tuning Loss = 0.6898097991943359
# 103) Lyapunov Risk = 2.5635910034179688, MSE = 0.125074565410614, V_0_loss = tensor([[0.2264]], grad_fn=<PowBackward0>), V_pos_loss = 0.4609506130218506, Lv_loss = 0.0004362973559182137, Circular Tuning Loss = 0.6890507340431213
# 104) Lyapunov Risk = 2.560288429260254, MSE = 0.12066908925771713, V_0_loss = tensor([[0.2259]], grad_fn=<PowBackward0>), V_pos_loss = 0.46042120456695557, Lv_loss = 0.000487658369820565, Circular Tuning Loss = 0.6882913708686829
# 105) Lyapunov Risk = 2.5551199913024902, MSE = 0.12966398894786835, V_0_loss = tensor([[0.2253]], grad_fn=<PowBackward0>), V_pos_loss = 0.4598912000656128, Lv_loss = 0.00042323447996750474, Circular Tuning Loss = 0.6875319480895996
# 106) Lyapunov Risk = 2.5492911338806152, MSE = 0.1499948799610138, V_0_loss = tensor([[0.2248]], grad_fn=<PowBackward0>), V_pos_loss = 0.45936068892478943, Lv_loss = 0.0003012064553331584, Circular Tuning Loss = 0.6867721676826477
# 107) Lyapunov Risk = 2.555309772491455, MSE = 0.17778970301151276, V_0_loss = tensor([[0.2243]], grad_fn=<PowBackward0>), V_pos_loss = 0.4588295817375183, Lv_loss = 0.0002054127980954945, Circular Tuning Loss = 0.6860120296478271
# 108) Lyapunov Risk = 2.54178786277771, MSE = 0.14486035704612732, V_0_loss = tensor([[0.2238]], grad_fn=<PowBackward0>), V_pos_loss = 0.45830008387565613, Lv_loss = 0.0003482773608993739, Circular Tuning Loss = 0.6852549910545349
# 109) Lyapunov Risk = 2.5398378372192383, MSE = 0.12596528232097626, V_0_loss = tensor([[0.2232]], grad_fn=<PowBackward0>), V_pos_loss = 0.4577697515487671, Lv_loss = 0.0004988565924577415, Circular Tuning Loss = 0.6844973564147949
# 110) Lyapunov Risk = 2.53654146194458, MSE = 0.1214742437005043, V_0_loss = tensor([[0.2227]], grad_fn=<PowBackward0>), V_pos_loss = 0.45723891258239746, Lv_loss = 0.0005458983941935003, Circular Tuning Loss = 0.6837394833564758
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 111) Lyapunov Risk = 2.5301644802093506, MSE = 0.1301732361316681, V_0_loss = tensor([[0.2222]], grad_fn=<PowBackward0>), V_pos_loss = 0.456760048866272, Lv_loss = 0.0004784304474014789, Circular Tuning Loss = 0.6813360452651978
# 112) Lyapunov Risk = 2.5243875980377197, MSE = 0.15002910792827606, V_0_loss = tensor([[0.2217]], grad_fn=<PowBackward0>), V_pos_loss = 0.4562281668186188, Lv_loss = 0.00034858682192862034, Circular Tuning Loss = 0.6805785894393921
# 113) Lyapunov Risk = 2.530715227127075, MSE = 0.17737513780593872, V_0_loss = tensor([[0.2212]], grad_fn=<PowBackward0>), V_pos_loss = 0.4556958079338074, Lv_loss = 0.000241765781538561, Circular Tuning Loss = 0.6798209547996521
# 114) Lyapunov Risk = 2.516911506652832, MSE = 0.1449379324913025, V_0_loss = tensor([[0.2206]], grad_fn=<PowBackward0>), V_pos_loss = 0.45516517758369446, Lv_loss = 0.00039877183735370636, Circular Tuning Loss = 0.6790662407875061
# 115) Lyapunov Risk = 2.5149474143981934, MSE = 0.1265878677368164, V_0_loss = tensor([[0.2201]], grad_fn=<PowBackward0>), V_pos_loss = 0.4546339213848114, Lv_loss = 0.0005506858578883111, Circular Tuning Loss = 0.6783110499382019
# 116) Lyapunov Risk = 2.5116326808929443, MSE = 0.12236613780260086, V_0_loss = tensor([[0.2196]], grad_fn=<PowBackward0>), V_pos_loss = 0.45410221815109253, Lv_loss = 0.000597283011302352, Circular Tuning Loss = 0.6775555610656738
# 117) Lyapunov Risk = 2.5065438747406006, MSE = 0.13111180067062378, V_0_loss = tensor([[0.2191]], grad_fn=<PowBackward0>), V_pos_loss = 0.45357006788253784, Lv_loss = 0.0005349961575120687, Circular Tuning Loss = 0.676800012588501
# 118) Lyapunov Risk = 2.500795364379883, MSE = 0.15084144473075867, V_0_loss = tensor([[0.2185]], grad_fn=<PowBackward0>), V_pos_loss = 0.4530373811721802, Lv_loss = 0.0004009180120192468, Circular Tuning Loss = 0.6760443449020386
# 119) Lyapunov Risk = 2.5079634189605713, MSE = 0.17792479693889618, V_0_loss = tensor([[0.2180]], grad_fn=<PowBackward0>), V_pos_loss = 0.45250406861305237, Lv_loss = 0.00028635896160267293, Circular Tuning Loss = 0.6752881407737732
# 120) Lyapunov Risk = 2.4933419227600098, MSE = 0.1458081603050232, V_0_loss = tensor([[0.2175]], grad_fn=<PowBackward0>), V_pos_loss = 0.4519723951816559, Lv_loss = 0.0004598922678269446, Circular Tuning Loss = 0.6745349764823914
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 121) Lyapunov Risk = 2.49009370803833, MSE = 0.1275234818458557, V_0_loss = tensor([[0.2170]], grad_fn=<PowBackward0>), V_pos_loss = 0.451491117477417, Lv_loss = 0.0006109351525083184, Circular Tuning Loss = 0.6721561551094055
# 122) Lyapunov Risk = 2.4867920875549316, MSE = 0.12322089821100235, V_0_loss = tensor([[0.2165]], grad_fn=<PowBackward0>), V_pos_loss = 0.4509580433368683, Lv_loss = 0.0006591982091777027, Circular Tuning Loss = 0.6714031100273132
# 123) Lyapunov Risk = 2.481755018234253, MSE = 0.1317630410194397, V_0_loss = tensor([[0.2160]], grad_fn=<PowBackward0>), V_pos_loss = 0.45042455196380615, Lv_loss = 0.0005968382465653121, Circular Tuning Loss = 0.6706501245498657
# 124) Lyapunov Risk = 2.4760494232177734, MSE = 0.1511438935995102, V_0_loss = tensor([[0.2154]], grad_fn=<PowBackward0>), V_pos_loss = 0.4498906135559082, Lv_loss = 0.0004631566407624632, Circular Tuning Loss = 0.6698967814445496
# 125) Lyapunov Risk = 2.483717203140259, MSE = 0.17782694101333618, V_0_loss = tensor([[0.2149]], grad_fn=<PowBackward0>), V_pos_loss = 0.4493561089038849, Lv_loss = 0.000337899022269994, Circular Tuning Loss = 0.6691431403160095
# 126) Lyapunov Risk = 2.4686288833618164, MSE = 0.14605745673179626, V_0_loss = tensor([[0.2144]], grad_fn=<PowBackward0>), V_pos_loss = 0.4488232135772705, Lv_loss = 0.0005261293263174593, Circular Tuning Loss = 0.6683925986289978
# 127) Lyapunov Risk = 2.4666502475738525, MSE = 0.12801972031593323, V_0_loss = tensor([[0.2139]], grad_fn=<PowBackward0>), V_pos_loss = 0.4482896327972412, Lv_loss = 0.0006814678199589252, Circular Tuning Loss = 0.6676415205001831
# 128) Lyapunov Risk = 2.463355779647827, MSE = 0.12376623600721359, V_0_loss = tensor([[0.2134]], grad_fn=<PowBackward0>), V_pos_loss = 0.4477554261684418, Lv_loss = 0.0007325763581320643, Circular Tuning Loss = 0.6668902635574341
# 129) Lyapunov Risk = 2.458350658416748, MSE = 0.1321754902601242, V_0_loss = tensor([[0.2129]], grad_fn=<PowBackward0>), V_pos_loss = 0.44722092151641846, Lv_loss = 0.0006685008411295712, Circular Tuning Loss = 0.6661388278007507
# 130) Lyapunov Risk = 2.4526708126068115, MSE = 0.15132251381874084, V_0_loss = tensor([[0.2123]], grad_fn=<PowBackward0>), V_pos_loss = 0.44668611884117126, Lv_loss = 0.0005317700561136007, Circular Tuning Loss = 0.6653872132301331
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 131) Lyapunov Risk = 2.4595742225646973, MSE = 0.1777627021074295, V_0_loss = tensor([[0.2118]], grad_fn=<PowBackward0>), V_pos_loss = 0.44620075821876526, Lv_loss = 0.0003916095301974565, Circular Tuning Loss = 0.6630300283432007
# 132) Lyapunov Risk = 2.4440038204193115, MSE = 0.14651742577552795, V_0_loss = tensor([[0.2113]], grad_fn=<PowBackward0>), V_pos_loss = 0.44566696882247925, Lv_loss = 0.0005863829865120351, Circular Tuning Loss = 0.6622820496559143
# 133) Lyapunov Risk = 2.4420013427734375, MSE = 0.1288589984178543, V_0_loss = tensor([[0.2108]], grad_fn=<PowBackward0>), V_pos_loss = 0.4451325833797455, Lv_loss = 0.0007385901408270001, Circular Tuning Loss = 0.6615335941314697
# 134) Lyapunov Risk = 2.4386866092681885, MSE = 0.12481451779603958, V_0_loss = tensor([[0.2103]], grad_fn=<PowBackward0>), V_pos_loss = 0.44459766149520874, Lv_loss = 0.0007845848449505866, Circular Tuning Loss = 0.6607848405838013
# 135) Lyapunov Risk = 2.4337029457092285, MSE = 0.13331270217895508, V_0_loss = tensor([[0.2098]], grad_fn=<PowBackward0>), V_pos_loss = 0.4440622627735138, Lv_loss = 0.0007163617410697043, Circular Tuning Loss = 0.6600360870361328
# 136) Lyapunov Risk = 2.4288690090179443, MSE = 0.152391254901886, V_0_loss = tensor([[0.2093]], grad_fn=<PowBackward0>), V_pos_loss = 0.44352641701698303, Lv_loss = 0.000576453167013824, Circular Tuning Loss = 0.6592872142791748
# 137) Lyapunov Risk = 2.427116632461548, MSE = 0.12456818670034409, V_0_loss = tensor([[0.2088]], grad_fn=<PowBackward0>), V_pos_loss = 0.44299212098121643, Lv_loss = 0.0007782634347677231, Circular Tuning Loss = 0.6585414409637451
# 138) Lyapunov Risk = 2.4251441955566406, MSE = 0.1130206286907196, V_0_loss = tensor([[0.2082]], grad_fn=<PowBackward0>), V_pos_loss = 0.4424572288990021, Lv_loss = 0.0008660085732117295, Circular Tuning Loss = 0.657795250415802
# 139) Lyapunov Risk = 2.420715808868408, MSE = 0.11634089052677155, V_0_loss = tensor([[0.2077]], grad_fn=<PowBackward0>), V_pos_loss = 0.44192206859588623, Lv_loss = 0.000811480451375246, Circular Tuning Loss = 0.6570491194725037
# 140) Lyapunov Risk = 2.4145567417144775, MSE = 0.13290072977542877, V_0_loss = tensor([[0.2072]], grad_fn=<PowBackward0>), V_pos_loss = 0.44138625264167786, Lv_loss = 0.0006462046876549721, Circular Tuning Loss = 0.656302809715271
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 141) Lyapunov Risk = 2.4117136001586914, MSE = 0.16009896993637085, V_0_loss = tensor([[0.2067]], grad_fn=<PowBackward0>), V_pos_loss = 0.44089871644973755, Lv_loss = 0.00044913560850545764, Circular Tuning Loss = 0.6539705991744995
# 142) Lyapunov Risk = 2.405222177505493, MSE = 0.13667552173137665, V_0_loss = tensor([[0.2062]], grad_fn=<PowBackward0>), V_pos_loss = 0.44036394357681274, Lv_loss = 0.0005872021429240704, Circular Tuning Loss = 0.6532279253005981
# 143) Lyapunov Risk = 2.402629852294922, MSE = 0.1265026181936264, V_0_loss = tensor([[0.2057]], grad_fn=<PowBackward0>), V_pos_loss = 0.43982839584350586, Lv_loss = 0.0006644525565207005, Circular Tuning Loss = 0.6524847745895386
# 144) Lyapunov Risk = 2.3984758853912354, MSE = 0.12893430888652802, V_0_loss = tensor([[0.2052]], grad_fn=<PowBackward0>), V_pos_loss = 0.43929222226142883, Lv_loss = 0.0006494990666396916, Circular Tuning Loss = 0.6517413258552551
# 145) Lyapunov Risk = 2.3930892944335938, MSE = 0.14257369935512543, V_0_loss = tensor([[0.2047]], grad_fn=<PowBackward0>), V_pos_loss = 0.4387556314468384, Lv_loss = 0.000555889739189297, Circular Tuning Loss = 0.6509976387023926
# 146) Lyapunov Risk = 2.3949437141418457, MSE = 0.16512370109558105, V_0_loss = tensor([[0.2042]], grad_fn=<PowBackward0>), V_pos_loss = 0.43821850419044495, Lv_loss = 0.00044209789484739304, Circular Tuning Loss = 0.6502536535263062
# 147) Lyapunov Risk = 2.3859922885894775, MSE = 0.13700167834758759, V_0_loss = tensor([[0.2037]], grad_fn=<PowBackward0>), V_pos_loss = 0.43768274784088135, Lv_loss = 0.000630425289273262, Circular Tuning Loss = 0.6495124101638794
# 148) Lyapunov Risk = 2.383941173553467, MSE = 0.12328315526247025, V_0_loss = tensor([[0.2032]], grad_fn=<PowBackward0>), V_pos_loss = 0.4371463358402252, Lv_loss = 0.0007607240695506334, Circular Tuning Loss = 0.6487706899642944
# 149) Lyapunov Risk = 2.380091667175293, MSE = 0.12310119718313217, V_0_loss = tensor([[0.2027]], grad_fn=<PowBackward0>), V_pos_loss = 0.43660932779312134, Lv_loss = 0.0007799480226822197, Circular Tuning Loss = 0.6480287313461304
# 150) Lyapunov Risk = 2.3746519088745117, MSE = 0.13511596620082855, V_0_loss = tensor([[0.2021]], grad_fn=<PowBackward0>), V_pos_loss = 0.4360717833042145, Lv_loss = 0.0006983556086197495, Circular Tuning Loss = 0.6472866535186768
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 151) Lyapunov Risk = 2.37133526802063, MSE = 0.15725642442703247, V_0_loss = tensor([[0.2016]], grad_fn=<PowBackward0>), V_pos_loss = 0.4355812668800354, Lv_loss = 0.000558519852347672, Circular Tuning Loss = 0.6449779868125916
# 152) Lyapunov Risk = 2.3662288188934326, MSE = 0.13138996064662933, V_0_loss = tensor([[0.2011]], grad_fn=<PowBackward0>), V_pos_loss = 0.4350445866584778, Lv_loss = 0.0007605203427374363, Circular Tuning Loss = 0.6442393064498901
# 153) Lyapunov Risk = 2.363999366760254, MSE = 0.11998144537210464, V_0_loss = tensor([[0.2006]], grad_fn=<PowBackward0>), V_pos_loss = 0.43450725078582764, Lv_loss = 0.0008747069514356554, Circular Tuning Loss = 0.6435002088546753
# 154) Lyapunov Risk = 2.3598453998565674, MSE = 0.12209413200616837, V_0_loss = tensor([[0.2001]], grad_fn=<PowBackward0>), V_pos_loss = 0.4339693784713745, Lv_loss = 0.0008726566447876394, Circular Tuning Loss = 0.6427610516548157
# 155) Lyapunov Risk = 2.3541741371154785, MSE = 0.1362265944480896, V_0_loss = tensor([[0.1996]], grad_fn=<PowBackward0>), V_pos_loss = 0.4334310293197632, Lv_loss = 0.0007719750283285975, Circular Tuning Loss = 0.642021656036377
# 156) Lyapunov Risk = 2.353950023651123, MSE = 0.16017161309719086, V_0_loss = tensor([[0.1991]], grad_fn=<PowBackward0>), V_pos_loss = 0.43289244174957275, Lv_loss = 0.0006156075978651643, Circular Tuning Loss = 0.6412821412086487
# 157) Lyapunov Risk = 2.3466110229492188, MSE = 0.13548099994659424, V_0_loss = tensor([[0.1986]], grad_fn=<PowBackward0>), V_pos_loss = 0.43235525488853455, Lv_loss = 0.0008087663445621729, Circular Tuning Loss = 0.6405452489852905
# 158) Lyapunov Risk = 2.3442468643188477, MSE = 0.12456850707530975, V_0_loss = tensor([[0.1981]], grad_fn=<PowBackward0>), V_pos_loss = 0.4318173825740814, Lv_loss = 0.000913392985239625, Circular Tuning Loss = 0.6398079991340637
# 159) Lyapunov Risk = 2.3401591777801514, MSE = 0.12654070556163788, V_0_loss = tensor([[0.1976]], grad_fn=<PowBackward0>), V_pos_loss = 0.43127888441085815, Lv_loss = 0.0009060406591743231, Circular Tuning Loss = 0.6390705108642578
# 160) Lyapunov Risk = 2.334691047668457, MSE = 0.1399950236082077, V_0_loss = tensor([[0.1971]], grad_fn=<PowBackward0>), V_pos_loss = 0.43073996901512146, Lv_loss = 0.0008039288804866374, Circular Tuning Loss = 0.638332724571228
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 161) Lyapunov Risk = 2.3351893424987793, MSE = 0.16277499496936798, V_0_loss = tensor([[0.1966]], grad_fn=<PowBackward0>), V_pos_loss = 0.43024691939353943, Lv_loss = 0.0006463544559665024, Circular Tuning Loss = 0.6360477209091187
# 162) Lyapunov Risk = 2.326228141784668, MSE = 0.13681869208812714, V_0_loss = tensor([[0.1961]], grad_fn=<PowBackward0>), V_pos_loss = 0.429708868265152, Lv_loss = 0.0008405362605117261, Circular Tuning Loss = 0.6353133320808411
# 163) Lyapunov Risk = 2.3240127563476562, MSE = 0.1246534213423729, V_0_loss = tensor([[0.1956]], grad_fn=<PowBackward0>), V_pos_loss = 0.4291701018810272, Lv_loss = 0.0009512732503935695, Circular Tuning Loss = 0.63457852602005
# 164) Lyapunov Risk = 2.3200900554656982, MSE = 0.1254880130290985, V_0_loss = tensor([[0.1951]], grad_fn=<PowBackward0>), V_pos_loss = 0.4286307692527771, Lv_loss = 0.0009510220843367279, Circular Tuning Loss = 0.6338435411453247
# 165) Lyapunov Risk = 2.314725160598755, MSE = 0.1379285454750061, V_0_loss = tensor([[0.1946]], grad_fn=<PowBackward0>), V_pos_loss = 0.4280909597873688, Lv_loss = 0.0008536874083802104, Circular Tuning Loss = 0.6331083178520203
# 166) Lyapunov Risk = 2.3151304721832275, MSE = 0.15987150371074677, V_0_loss = tensor([[0.1941]], grad_fn=<PowBackward0>), V_pos_loss = 0.42755061388015747, Lv_loss = 0.0007040842901915312, Circular Tuning Loss = 0.6323729157447815
# 167) Lyapunov Risk = 2.3075501918792725, MSE = 0.1343681365251541, V_0_loss = tensor([[0.1936]], grad_fn=<PowBackward0>), V_pos_loss = 0.427011638879776, Lv_loss = 0.0009008452179841697, Circular Tuning Loss = 0.6316403150558472
# 168) Lyapunov Risk = 2.30533766746521, MSE = 0.12287027388811111, V_0_loss = tensor([[0.1931]], grad_fn=<PowBackward0>), V_pos_loss = 0.42647212743759155, Lv_loss = 0.0010122907115146518, Circular Tuning Loss = 0.6309072971343994
# 169) Lyapunov Risk = 2.3013226985931396, MSE = 0.12444692105054855, V_0_loss = tensor([[0.1926]], grad_fn=<PowBackward0>), V_pos_loss = 0.4259321391582489, Lv_loss = 0.0010059092892333865, Circular Tuning Loss = 0.6301741600036621
# 170) Lyapunov Risk = 2.2958197593688965, MSE = 0.13771438598632812, V_0_loss = tensor([[0.1921]], grad_fn=<PowBackward0>), V_pos_loss = 0.4253917336463928, Lv_loss = 0.000896897807251662, Circular Tuning Loss = 0.6294408440589905
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 171) Lyapunov Risk = 2.295572280883789, MSE = 0.16055871546268463, V_0_loss = tensor([[0.1916]], grad_fn=<PowBackward0>), V_pos_loss = 0.4248960614204407, Lv_loss = 0.0007338906289078295, Circular Tuning Loss = 0.6271793246269226
# 172) Lyapunov Risk = 2.287264347076416, MSE = 0.1362362951040268, V_0_loss = tensor([[0.1911]], grad_fn=<PowBackward0>), V_pos_loss = 0.4243565797805786, Lv_loss = 0.0009179300395771861, Circular Tuning Loss = 0.6264493465423584
# 173) Lyapunov Risk = 2.2849297523498535, MSE = 0.12547333538532257, V_0_loss = tensor([[0.1906]], grad_fn=<PowBackward0>), V_pos_loss = 0.4238165616989136, Lv_loss = 0.0010186866857111454, Circular Tuning Loss = 0.6257190108299255
# 174) Lyapunov Risk = 2.2808868885040283, MSE = 0.12736177444458008, V_0_loss = tensor([[0.1902]], grad_fn=<PowBackward0>), V_pos_loss = 0.42327597737312317, Lv_loss = 0.0010075356112793088, Circular Tuning Loss = 0.6249884366989136
# 175) Lyapunov Risk = 2.2754909992218018, MSE = 0.14054639637470245, V_0_loss = tensor([[0.1897]], grad_fn=<PowBackward0>), V_pos_loss = 0.4227351248264313, Lv_loss = 0.0009013529634103179, Circular Tuning Loss = 0.6242578625679016
# 176) Lyapunov Risk = 2.278001308441162, MSE = 0.16289016604423523, V_0_loss = tensor([[0.1892]], grad_fn=<PowBackward0>), V_pos_loss = 0.4221937954425812, Lv_loss = 0.0007480512140318751, Circular Tuning Loss = 0.623526930809021
# 177) Lyapunov Risk = 2.2682833671569824, MSE = 0.13769493997097015, V_0_loss = tensor([[0.1887]], grad_fn=<PowBackward0>), V_pos_loss = 0.4216538965702057, Lv_loss = 0.0009406915050931275, Circular Tuning Loss = 0.6227988600730896
# 178) Lyapunov Risk = 2.2660534381866455, MSE = 0.12596215307712555, V_0_loss = tensor([[0.1882]], grad_fn=<PowBackward0>), V_pos_loss = 0.42111361026763916, Lv_loss = 0.001052789855748415, Circular Tuning Loss = 0.6220703721046448
# 179) Lyapunov Risk = 2.2621700763702393, MSE = 0.12686540186405182, V_0_loss = tensor([[0.1877]], grad_fn=<PowBackward0>), V_pos_loss = 0.4205726087093353, Lv_loss = 0.0010530027793720365, Circular Tuning Loss = 0.6213417053222656
# 180) Lyapunov Risk = 2.2568721771240234, MSE = 0.13908353447914124, V_0_loss = tensor([[0.1872]], grad_fn=<PowBackward0>), V_pos_loss = 0.42003142833709717, Lv_loss = 0.0009543532505631447, Circular Tuning Loss = 0.6206129193305969
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 181) Lyapunov Risk = 2.257207155227661, MSE = 0.1605713814496994, V_0_loss = tensor([[0.1867]], grad_fn=<PowBackward0>), V_pos_loss = 0.41953375935554504, Lv_loss = 0.0008011524914763868, Circular Tuning Loss = 0.6183748841285706
# 182) Lyapunov Risk = 2.248594045639038, MSE = 0.13580353558063507, V_0_loss = tensor([[0.1862]], grad_fn=<PowBackward0>), V_pos_loss = 0.41899341344833374, Lv_loss = 0.0009955178247764707, Circular Tuning Loss = 0.6176495552062988
# 183) Lyapunov Risk = 2.2463672161102295, MSE = 0.12470700591802597, V_0_loss = tensor([[0.1857]], grad_fn=<PowBackward0>), V_pos_loss = 0.4184524714946747, Lv_loss = 0.0011017529759556055, Circular Tuning Loss = 0.6169237494468689
# 184) Lyapunov Risk = 2.242386817932129, MSE = 0.1263273060321808, V_0_loss = tensor([[0.1852]], grad_fn=<PowBackward0>), V_pos_loss = 0.4179110825061798, Lv_loss = 0.0010930484859272838, Circular Tuning Loss = 0.6161980032920837
# 185) Lyapunov Risk = 2.2369837760925293, MSE = 0.1393166035413742, V_0_loss = tensor([[0.1847]], grad_fn=<PowBackward0>), V_pos_loss = 0.41736921668052673, Lv_loss = 0.0009853743249550462, Circular Tuning Loss = 0.615472137928009
# 186) Lyapunov Risk = 2.239168643951416, MSE = 0.1615973860025406, V_0_loss = tensor([[0.1843]], grad_fn=<PowBackward0>), V_pos_loss = 0.41682687401771545, Lv_loss = 0.0008266817894764245, Circular Tuning Loss = 0.61474609375
# 187) Lyapunov Risk = 2.2297208309173584, MSE = 0.13756990432739258, V_0_loss = tensor([[0.1838]], grad_fn=<PowBackward0>), V_pos_loss = 0.4162859618663788, Lv_loss = 0.0010140868835151196, Circular Tuning Loss = 0.6140226721763611
# 188) Lyapunov Risk = 2.2274200916290283, MSE = 0.12669537961483002, V_0_loss = tensor([[0.1833]], grad_fn=<PowBackward0>), V_pos_loss = 0.415744423866272, Lv_loss = 0.0011176120024174452, Circular Tuning Loss = 0.6132990121841431
# 189) Lyapunov Risk = 2.223482847213745, MSE = 0.1281861811876297, V_0_loss = tensor([[0.1828]], grad_fn=<PowBackward0>), V_pos_loss = 0.41520237922668457, Lv_loss = 0.001110921846702695, Circular Tuning Loss = 0.612575113773346
# 190) Lyapunov Risk = 2.2182023525238037, MSE = 0.1407286673784256, V_0_loss = tensor([[0.1823]], grad_fn=<PowBackward0>), V_pos_loss = 0.4146598279476166, Lv_loss = 0.001008839113637805, Circular Tuning Loss = 0.6118512153625488
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# ...
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 281) Lyapunov Risk = 1.886250615119934, MSE = 0.11719633638858795, V_0_loss = tensor([[0.1404]], grad_fn=<PowBackward0>), V_pos_loss = 0.3653092086315155, Lv_loss = 0.001838936936110258, Circular Tuning Loss = 0.5342194437980652
# 282) Lyapunov Risk = 1.8824363946914673, MSE = 0.11918710917234421, V_0_loss = tensor([[0.1400]], grad_fn=<PowBackward0>), V_pos_loss = 0.3647608160972595, Lv_loss = 0.001824597013182938, Circular Tuning Loss = 0.5335495471954346
# 283) Lyapunov Risk = 1.8768537044525146, MSE = 0.13257688283920288, V_0_loss = tensor([[0.1395]], grad_fn=<PowBackward0>), V_pos_loss = 0.36421218514442444, Lv_loss = 0.00169001379981637, Circular Tuning Loss = 0.5328798890113831
# 284) Lyapunov Risk = 1.8775995969772339, MSE = 0.15574757754802704, V_0_loss = tensor([[0.1391]], grad_fn=<PowBackward0>), V_pos_loss = 0.36366331577301025, Lv_loss = 0.0014889921294525266, Circular Tuning Loss = 0.5322103500366211
# 285) Lyapunov Risk = 1.869162678718567, MSE = 0.13984699547290802, V_0_loss = tensor([[0.1387]], grad_fn=<PowBackward0>), V_pos_loss = 0.3631153702735901, Lv_loss = 0.0016207542503252625, Circular Tuning Loss = 0.531542956829071
# 286) Lyapunov Risk = 1.8664321899414062, MSE = 0.13453444838523865, V_0_loss = tensor([[0.1382]], grad_fn=<PowBackward0>), V_pos_loss = 0.36256715655326843, Lv_loss = 0.001676172949373722, Circular Tuning Loss = 0.530875563621521
# 287) Lyapunov Risk = 1.8624759912490845, MSE = 0.13897928595542908, V_0_loss = tensor([[0.1378]], grad_fn=<PowBackward0>), V_pos_loss = 0.3620186746120453, Lv_loss = 0.0016490609850734472, Circular Tuning Loss = 0.5302083492279053
# 288) Lyapunov Risk = 1.8623195886611938, MSE = 0.1519782692193985, V_0_loss = tensor([[0.1374]], grad_fn=<PowBackward0>), V_pos_loss = 0.36146989464759827, Lv_loss = 0.0015567238442599773, Circular Tuning Loss = 0.5295413136482239
# 289) Lyapunov Risk = 1.857133388519287, MSE = 0.12844784557819366, V_0_loss = tensor([[0.1370]], grad_fn=<PowBackward0>), V_pos_loss = 0.36092209815979004, Lv_loss = 0.0017813327722251415, Circular Tuning Loss = 0.5288763046264648
# 290) Lyapunov Risk = 1.8554601669311523, MSE = 0.11850365996360779, V_0_loss = tensor([[0.1365]], grad_fn=<PowBackward0>), V_pos_loss = 0.36037421226501465, Lv_loss = 0.0018919131252914667, Circular Tuning Loss = 0.5282112956047058
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 291) Lyapunov Risk = 1.8506958484649658, MSE = 0.12079865485429764, V_0_loss = tensor([[0.1361]], grad_fn=<PowBackward0>), V_pos_loss = 0.3598567545413971, Lv_loss = 0.0018607203382998705, Circular Tuning Loss = 0.5262331962585449
# 292) Lyapunov Risk = 1.8452354669570923, MSE = 0.13413944840431213, V_0_loss = tensor([[0.1357]], grad_fn=<PowBackward0>), V_pos_loss = 0.35930851101875305, Lv_loss = 0.0017227892531082034, Circular Tuning Loss = 0.525569498538971
# 293) Lyapunov Risk = 1.8466616868972778, MSE = 0.1568843275308609, V_0_loss = tensor([[0.1352]], grad_fn=<PowBackward0>), V_pos_loss = 0.35875996947288513, Lv_loss = 0.0015238403575494885, Circular Tuning Loss = 0.5249060988426208
# 294) Lyapunov Risk = 1.8377034664154053, MSE = 0.1407502442598343, V_0_loss = tensor([[0.1348]], grad_fn=<PowBackward0>), V_pos_loss = 0.35821235179901123, Lv_loss = 0.0016579338116571307, Circular Tuning Loss = 0.5242446660995483
# 295) Lyapunov Risk = 1.8350520133972168, MSE = 0.1350615918636322, V_0_loss = tensor([[0.1344]], grad_fn=<PowBackward0>), V_pos_loss = 0.3576643764972687, Lv_loss = 0.0017189224017784, Circular Tuning Loss = 0.5235833525657654
# 296) Lyapunov Risk = 1.8311898708343506, MSE = 0.13906672596931458, V_0_loss = tensor([[0.1340]], grad_fn=<PowBackward0>), V_pos_loss = 0.3571162223815918, Lv_loss = 0.0016972714802250266, Circular Tuning Loss = 0.522922158241272
# 297) Lyapunov Risk = 1.830822467803955, MSE = 0.1515871286392212, V_0_loss = tensor([[0.1335]], grad_fn=<PowBackward0>), V_pos_loss = 0.3565678298473358, Lv_loss = 0.0016096662729978561, Circular Tuning Loss = 0.5222611427307129
# 298) Lyapunov Risk = 1.8259739875793457, MSE = 0.128202423453331, V_0_loss = tensor([[0.1331]], grad_fn=<PowBackward0>), V_pos_loss = 0.3560202419757843, Lv_loss = 0.0018346188589930534, Circular Tuning Loss = 0.521602213382721
# 299) Lyapunov Risk = 1.8243305683135986, MSE = 0.11823825538158417, V_0_loss = tensor([[0.1327]], grad_fn=<PowBackward0>), V_pos_loss = 0.3554723560810089, Lv_loss = 0.0019482418429106474, Circular Tuning Loss = 0.520943284034729
# 300) Lyapunov Risk = 1.8205870389938354, MSE = 0.12041714042425156, V_0_loss = tensor([[0.1323]], grad_fn=<PowBackward0>), V_pos_loss = 0.35492435097694397, Lv_loss = 0.0019264480797573924, Circular Tuning Loss = 0.5202847123146057
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 301) Lyapunov Risk = 1.8142458200454712, MSE = 0.1334649920463562, V_0_loss = tensor([[0.1319]], grad_fn=<PowBackward0>), V_pos_loss = 0.35440555214881897, Lv_loss = 0.0017860551597550511, Circular Tuning Loss = 0.5183296799659729
# 302) Lyapunov Risk = 1.815055251121521, MSE = 0.15582165122032166, V_0_loss = tensor([[0.1314]], grad_fn=<PowBackward0>), V_pos_loss = 0.35385724902153015, Lv_loss = 0.0015904171159490943, Circular Tuning Loss = 0.5176724195480347
# 303) Lyapunov Risk = 1.8067917823791504, MSE = 0.13998648524284363, V_0_loss = tensor([[0.1310]], grad_fn=<PowBackward0>), V_pos_loss = 0.3533097505569458, Lv_loss = 0.0017231233650818467, Circular Tuning Loss = 0.517017126083374
# 304) Lyapunov Risk = 1.8041508197784424, MSE = 0.13454660773277283, V_0_loss = tensor([[0.1306]], grad_fn=<PowBackward0>), V_pos_loss = 0.3527619242668152, Lv_loss = 0.001780827296897769, Circular Tuning Loss = 0.5163619518280029
# 305) Lyapunov Risk = 1.8002994060516357, MSE = 0.13871753215789795, V_0_loss = tensor([[0.1302]], grad_fn=<PowBackward0>), V_pos_loss = 0.35221391916275024, Lv_loss = 0.0017551812343299389, Circular Tuning Loss = 0.5157070159912109
# 306) Lyapunov Risk = 1.7997016906738281, MSE = 0.15133561193943024, V_0_loss = tensor([[0.1298]], grad_fn=<PowBackward0>), V_pos_loss = 0.35166579484939575, Lv_loss = 0.0016630995087325573, Circular Tuning Loss = 0.5150521397590637
# 307) Lyapunov Risk = 1.795079231262207, MSE = 0.12852144241333008, V_0_loss = tensor([[0.1294]], grad_fn=<PowBackward0>), V_pos_loss = 0.3511185944080353, Lv_loss = 0.001880376716144383, Circular Tuning Loss = 0.5143994092941284
# 308) Lyapunov Risk = 1.7934075593948364, MSE = 0.11890760809183121, V_0_loss = tensor([[0.1289]], grad_fn=<PowBackward0>), V_pos_loss = 0.3505711853504181, Lv_loss = 0.0019877583254128695, Circular Tuning Loss = 0.5137466192245483
# 309) Lyapunov Risk = 1.7896825075149536, MSE = 0.1211942657828331, V_0_loss = tensor([[0.1285]], grad_fn=<PowBackward0>), V_pos_loss = 0.3500235974788666, Lv_loss = 0.001962910871952772, Circular Tuning Loss = 0.5130943059921265
# 310) Lyapunov Risk = 1.784386157989502, MSE = 0.13411352038383484, V_0_loss = tensor([[0.1281]], grad_fn=<PowBackward0>), V_pos_loss = 0.34947583079338074, Lv_loss = 0.0018290444277226925, Circular Tuning Loss = 0.5124422907829285
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 311) Lyapunov Risk = 1.7843400239944458, MSE = 0.15610487759113312, V_0_loss = tensor([[0.1277]], grad_fn=<PowBackward0>), V_pos_loss = 0.34895604848861694, Lv_loss = 0.001629775739274919, Circular Tuning Loss = 0.5105103254318237
# 312) Lyapunov Risk = 1.7761062383651733, MSE = 0.1402641385793686, V_0_loss = tensor([[0.1273]], grad_fn=<PowBackward0>), V_pos_loss = 0.3484090268611908, Lv_loss = 0.0017628847854211926, Circular Tuning Loss = 0.5098612308502197
# 313) Lyapunov Risk = 1.7735196352005005, MSE = 0.1346508413553238, V_0_loss = tensor([[0.1269]], grad_fn=<PowBackward0>), V_pos_loss = 0.34786170721054077, Lv_loss = 0.0018238355405628681, Circular Tuning Loss = 0.5092123746871948
# 314) Lyapunov Risk = 1.7697407007217407, MSE = 0.13853083550930023, V_0_loss = tensor([[0.1265]], grad_fn=<PowBackward0>), V_pos_loss = 0.34731417894363403, Lv_loss = 0.0018030941719189286, Circular Tuning Loss = 0.5085636377334595
# 315) Lyapunov Risk = 1.7687469720840454, MSE = 0.15076524019241333, V_0_loss = tensor([[0.1261]], grad_fn=<PowBackward0>), V_pos_loss = 0.34676653146743774, Lv_loss = 0.0017163626616820693, Circular Tuning Loss = 0.507915198802948
# 316) Lyapunov Risk = 1.7646266222000122, MSE = 0.12809257209300995, V_0_loss = tensor([[0.1256]], grad_fn=<PowBackward0>), V_pos_loss = 0.3462194800376892, Lv_loss = 0.0019360866863280535, Circular Tuning Loss = 0.5072687268257141
# 317) Lyapunov Risk = 1.7629913091659546, MSE = 0.11853522807359695, V_0_loss = tensor([[0.1252]], grad_fn=<PowBackward0>), V_pos_loss = 0.34567245841026306, Lv_loss = 0.00204540160484612, Circular Tuning Loss = 0.506622314453125
# 318) Lyapunov Risk = 1.7593101263046265, MSE = 0.12077713757753372, V_0_loss = tensor([[0.1248]], grad_fn=<PowBackward0>), V_pos_loss = 0.3451251685619354, Lv_loss = 0.002024677349254489, Circular Tuning Loss = 0.5059763193130493
# 319) Lyapunov Risk = 1.7540507316589355, MSE = 0.13357830047607422, V_0_loss = tensor([[0.1244]], grad_fn=<PowBackward0>), V_pos_loss = 0.34457775950431824, Lv_loss = 0.0018932471284642816, Circular Tuning Loss = 0.5053306221961975
# 320) Lyapunov Risk = 1.7544819116592407, MSE = 0.15538793802261353, V_0_loss = tensor([[0.1240]], grad_fn=<PowBackward0>), V_pos_loss = 0.34403032064437866, Lv_loss = 0.0017015369376167655, Circular Tuning Loss = 0.5046852231025696
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 321) Lyapunov Risk = 1.7458155155181885, MSE = 0.1399998813867569, V_0_loss = tensor([[0.1236]], grad_fn=<PowBackward0>), V_pos_loss = 0.34351038932800293, Lv_loss = 0.001826331252232194, Circular Tuning Loss = 0.5027778744697571
# 322) Lyapunov Risk = 1.7432270050048828, MSE = 0.13472427427768707, V_0_loss = tensor([[0.1232]], grad_fn=<PowBackward0>), V_pos_loss = 0.34296348690986633, Lv_loss = 0.001882285694591701, Circular Tuning Loss = 0.5021353960037231
# 323) Lyapunov Risk = 1.7394671440124512, MSE = 0.1387883722782135, V_0_loss = tensor([[0.1228]], grad_fn=<PowBackward0>), V_pos_loss = 0.3424164056777954, Lv_loss = 0.0018581263720989227, Circular Tuning Loss = 0.5014930963516235
# 324) Lyapunov Risk = 1.738526463508606, MSE = 0.15105779469013214, V_0_loss = tensor([[0.1224]], grad_fn=<PowBackward0>), V_pos_loss = 0.3418692350387573, Lv_loss = 0.001769165974110365, Circular Tuning Loss = 0.5008511543273926
# 325) Lyapunov Risk = 1.7343717813491821, MSE = 0.12867368757724762, V_0_loss = tensor([[0.1220]], grad_fn=<PowBackward0>), V_pos_loss = 0.34132272005081177, Lv_loss = 0.0019854421261698008, Circular Tuning Loss = 0.5002109408378601
# 326) Lyapunov Risk = 1.7327452898025513, MSE = 0.11916171759366989, V_0_loss = tensor([[0.1216]], grad_fn=<PowBackward0>), V_pos_loss = 0.3407760262489319, Lv_loss = 0.0020923849660903215, Circular Tuning Loss = 0.4995709955692291
# 327) Lyapunov Risk = 1.7291315793991089, MSE = 0.12126956880092621, V_0_loss = tensor([[0.1212]], grad_fn=<PowBackward0>), V_pos_loss = 0.34022918343544006, Lv_loss = 0.002072685630992055, Circular Tuning Loss = 0.4989313781261444
# 328) Lyapunov Risk = 1.723973274230957, MSE = 0.13377133011817932, V_0_loss = tensor([[0.1208]], grad_fn=<PowBackward0>), V_pos_loss = 0.33968237042427063, Lv_loss = 0.0019443593919277191, Circular Tuning Loss = 0.4982922375202179
# 329) Lyapunov Risk = 1.724178433418274, MSE = 0.1551409214735031, V_0_loss = tensor([[0.1204]], grad_fn=<PowBackward0>), V_pos_loss = 0.33913546800613403, Lv_loss = 0.0017558808904141188, Circular Tuning Loss = 0.4976533353328705
# 330) Lyapunov Risk = 1.7168136835098267, MSE = 0.1397746056318283, V_0_loss = tensor([[0.1200]], grad_fn=<PowBackward0>), V_pos_loss = 0.338589072227478, Lv_loss = 0.0018867836333811283, Circular Tuning Loss = 0.49701622128486633
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 331) Lyapunov Risk = 1.7133480310440063, MSE = 0.13438789546489716, V_0_loss = tensor([[0.1196]], grad_fn=<PowBackward0>), V_pos_loss = 0.33806827664375305, Lv_loss = 0.001937091932632029, Circular Tuning Loss = 0.49513185024261475
# 332) Lyapunov Risk = 1.7096432447433472, MSE = 0.13829787075519562, V_0_loss = tensor([[0.1192]], grad_fn=<PowBackward0>), V_pos_loss = 0.337521493434906, Lv_loss = 0.001912810024805367, Circular Tuning Loss = 0.49449604749679565
# 333) Lyapunov Risk = 1.7081589698791504, MSE = 0.15036050975322723, V_0_loss = tensor([[0.1188]], grad_fn=<PowBackward0>), V_pos_loss = 0.3369746208190918, Lv_loss = 0.0018238559132441878, Circular Tuning Loss = 0.4938606023788452
# 334) Lyapunov Risk = 1.7046188116073608, MSE = 0.1282975971698761, V_0_loss = tensor([[0.1184]], grad_fn=<PowBackward0>), V_pos_loss = 0.33642831444740295, Lv_loss = 0.002037651604041457, Circular Tuning Loss = 0.49322691559791565
# 335) Lyapunov Risk = 1.7030086517333984, MSE = 0.11895223706960678, V_0_loss = tensor([[0.1180]], grad_fn=<PowBackward0>), V_pos_loss = 0.3358818590641022, Lv_loss = 0.002141918521374464, Circular Tuning Loss = 0.4925934970378876
# 336) Lyapunov Risk = 1.699432373046875, MSE = 0.1210649386048317, V_0_loss = tensor([[0.1176]], grad_fn=<PowBackward0>), V_pos_loss = 0.33533528447151184, Lv_loss = 0.0021206364035606384, Circular Tuning Loss = 0.49196046590805054
# 337) Lyapunov Risk = 1.6943224668502808, MSE = 0.13346832990646362, V_0_loss = tensor([[0.1172]], grad_fn=<PowBackward0>), V_pos_loss = 0.3347887098789215, Lv_loss = 0.001992959761992097, Circular Tuning Loss = 0.49132779240608215
# 338) Lyapunov Risk = 1.6940648555755615, MSE = 0.15463505685329437, V_0_loss = tensor([[0.1168]], grad_fn=<PowBackward0>), V_pos_loss = 0.3342421352863312, Lv_loss = 0.0018042835872620344, Circular Tuning Loss = 0.4906955063343048
# 339) Lyapunov Risk = 1.687227487564087, MSE = 0.13954699039459229, V_0_loss = tensor([[0.1164]], grad_fn=<PowBackward0>), V_pos_loss = 0.3336961269378662, Lv_loss = 0.0019330969080328941, Circular Tuning Loss = 0.4900648593902588
# 340) Lyapunov Risk = 1.6847093105316162, MSE = 0.13430440425872803, V_0_loss = tensor([[0.1160]], grad_fn=<PowBackward0>), V_pos_loss = 0.3331499397754669, Lv_loss = 0.001989209558814764, Circular Tuning Loss = 0.4894345700740814
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00010000000000000002, 0.00010000000000000002]
# x2 : [-0.00010000000000000002, 0.00010000000000000002]
# ==============================
# 341) Lyapunov Risk = 1.6801337003707886, MSE = 0.13817842304706573, V_0_loss = tensor([[0.1156]], grad_fn=<PowBackward0>), V_pos_loss = 0.33262813091278076, Lv_loss = 0.0019576014019548893, Circular Tuning Loss = 0.4875730872154236
# 342) Lyapunov Risk = 1.6783082485198975, MSE = 0.15009793639183044, V_0_loss = tensor([[0.1152]], grad_fn=<PowBackward0>), V_pos_loss = 0.3320818245410919, Lv_loss = 0.0018690997967496514, Circular Tuning Loss = 0.48694419860839844
# 343) Lyapunov Risk = 1.6751700639724731, MSE = 0.128294438123703, V_0_loss = tensor([[0.1148]], grad_fn=<PowBackward0>), V_pos_loss = 0.3315361738204956, Lv_loss = 0.0020809529814869165, Circular Tuning Loss = 0.4863170087337494

# %%
# Checking Result with Bounded Beta
beta = -0.02
start_ = timeit.default_timer() 
result = CheckLyapunov(vars_, f_learn, V_learn, ball_lb, ball_ub, config, beta)
stop_ = timeit.default_timer() 

if (result): 
    print("Not a Lyapunov function. Found counterexample: ")
    print(result)
else:  
    print("Satisfy conditions with beta = ",beta)
    print(V_learn, " is a Lyapunov function.")
t += (stop_ - start_)
# Out:
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.0010000000000000002, 0.0010000000000000002]
# x2 : [-0.0010000000000000002, 0.0010000000000000002]

# %%
beta = 0
f = [-2*x1 + x2,
        -x1 - 2*x2]
start_ = timeit.default_timer() 
result = CheckLyapunov(vars_, f, V_learn, ball_lb, ball_ub, config, beta)
stop_ = timeit.default_timer() 
if (result): 
    print("Not a Lyapunov function. Found counterexample: ")
    print(result)
else:  
    print("Satisfy conditions with beta= ", beta)
    print(V_learn, " is a Lyapunov function for actual dynamics.")
t += (stop_ - start_)
# Out:
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.00057325584229855312, 0.0010000000000000002]
# x2 : [-0.0010000000000000002, 0.0010000000000000002]

# %%
# Plotting the Lyapunov Function
fig, ax = plt.subplots()
# Define grid for plotting
len_sample = [256, 256]
x = np.linspace(-1, 1, len_sample[0])
y = np.linspace(-1, 1, len_sample[1])
X, Y = np.meshgrid(x, y)

# Convert X and Y to torch tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
Y_tensor = torch.tensor(Y, dtype=torch.float32)

# Concatenate X and Y to create input data tensor
input_data = torch.stack((X_tensor, Y_tensor), dim=-1).reshape(-1, 2)
unflatten = torch.nn.Unflatten(0, len_sample)

# Lyapunov Function
with torch.no_grad():
    V = model_v(input_data)
    cont_out = unflatten(V)
    cont_out = cont_out.detach().numpy()
# Plot the vector field
cp = ax.contourf(X, Y, cont_out[:,:,0])
fig.colorbar(cp)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Lyapunov Function')
plt.show()

# %%
# Plot the Lyapunov function in 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, cont_out[:,:,0], cmap='viridis')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('Lyapunov Function Value')
ax.set_title('Lyapunov Function')
plt.show()

# %% [markdown]
# ## Ideal Plots for the Lyapunov Function and the Vector Field

# %%
fig, ax = plt.subplots()
# Define grid for plotting
len_sample = [256, 256]
x = np.linspace(-1, 1, len_sample[0])
y = np.linspace(-1, 1, len_sample[1])
X, Y = np.meshgrid(x, y)

# Convert X and Y to torch tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
Y_tensor = torch.tensor(Y, dtype=torch.float32)

# Concatenate X and Y to create input data tensor
input_data = torch.stack((X_tensor, Y_tensor), dim=-1).reshape(-1, 2)
unflatten = torch.nn.Unflatten(0, len_sample)

# Vector Field
with torch.no_grad():
    F = torch.empty(len(input_data),2, dtype=torch.float32)
    for i in range(len(input_data)):
        x = input_data[i,:].unsqueeze(1)
        F[i,:] = torch.reshape(torch.matmul(A,x)[:],(1,-1))
    vect_out = unflatten(F)
    vect_out = vect_out.detach().numpy()
    U = vect_out[:,:, 0]
    V = vect_out[:,:,1]
ax.streamplot(X, Y, U, V, density=1.4, linewidth=None, color='b')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Vector Field for Neural Network Dynamical System')

# Lyapunov Function
V = torch.empty(len(input_data),1, dtype=torch.float32)
for i in range(len(input_data)):
    x = input_data[i,:]
    x_T = input_data[i,:].unsqueeze(1) 
    V[i] = torch.matmul(torch.matmul(x, P), x_T)
cont_out = unflatten(V)
cont_out = cont_out.detach().numpy()

# Plot the vector field
cp = ax.contourf(X, Y, cont_out[:,:,0])
fig.colorbar(cp)
plt.grid(True)
plt.show()

# %%
fig, ax = plt.subplots()
# Define grid for plotting
len_sample = [256, 256]
x = np.linspace(-1, 1, len_sample[0])
y = np.linspace(-1, 1, len_sample[1])
X, Y = np.meshgrid(x, y)

# Convert X and Y to torch tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
Y_tensor = torch.tensor(Y, dtype=torch.float32)

# Concatenate X and Y to create input data tensor
input_data = torch.stack((X_tensor, Y_tensor), dim=-1).reshape(-1, 2)
unflatten = torch.nn.Unflatten(0, len_sample)

# Vector Field
with torch.no_grad():
    F = model_f(input_data)
    vect_out = unflatten(F)
    vect_out = vect_out.detach().numpy()
    U = vect_out[:,:, 0]
    V = vect_out[:,:,1]
ax.streamplot(X, Y, U, V, density=1.4, linewidth=None, color='b')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Vector Field for Neural Network Dynamical System')

# Lyapunov Function
with torch.no_grad():
    V = model_v(input_data)
    cont_out = unflatten(V)
    cont_out = cont_out.detach().numpy()
# Plot the vector field
cp = ax.contourf(X, Y, cont_out[:,:,0])
fig.colorbar(cp)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Plot the Training Trajectories and the Output Trajectory taken by the model

# %%
# Plotting trajectories
t = np.linspace(0, 10, 1000)

for i in range(num_trajectories):
    x = np.zeros((len(t), 2))
    x_dot = np.zeros((len(t), 2))
    x[0] = x0_values[i]
    for j in range(1, len(t)):
        x_dot[j-1] = np.dot(A, x[j-1])
        x[j] = x[j-1] + x_dot[j-1] * (t[j] - t[j-1])
    X_data[i*len(t):(i+1)*len(t),:] = x
    X_dot_data[i*len(t):(i+1)*len(t),:] = x_dot
    plt.plot(x[:, 0], x[:, 1],'b')

# Plotting the final trajectory
x = torch.zeros((len(t), 2))
x[0] = torch.tensor([0.8,0.8], dtype=torch.float32)
for j in range(1, len(t)):
    x[j] = x[j-1] + model_f(x[j-1]) * (t[j] - t[j-1])
x = x.detach().numpy()
plt.plot(x[:, 0], x[:, 1],'r')

# Plotting the origin
#plt.plot(0, 0, 'ro')
#plt.text(0.1, 0.1, 'Origin (0, 0)', fontsize=10)

plt.xlabel('x')
plt.ylabel('y')
plt.title('100 Trajectories of the Linear Dynamical System')
plt.grid(True)
plt.axis('equal')
plt.show()
