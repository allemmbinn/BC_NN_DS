# %% [markdown]
# # Finding the Lyapunov Function using Counterexamples Method

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D

from scipy.linalg import solve_continuous_lyapunov
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
import torch.nn.functional as F

from dreal import *

import timeit 

import tqdm
import copy

# %% [markdown]
# ## Obtaining the Trajectories

# %%
# System matrix
A = np.array([[-2, 1], [-1, -2]])
region = [-1,1]
# Time
t = np.linspace(0, 10, 1000)

# Initial conditions
num_trajectories = 100
x0_values = np.random.uniform(low=0.8, high=1, size=(num_trajectories, 2))

X_data = np.zeros((len(t)*num_trajectories,2))
X_dot_data = np.zeros((len(t)*num_trajectories,2))

# Plotting trajectories
for i in range(num_trajectories):
    x = np.zeros((len(t), 2))
    x_dot = np.zeros((len(t), 2))
    x[0] = x0_values[i]
    for j in range(1, len(t)):
        x_dot[j-1] = np.dot(A, x[j-1])
        x[j] = x[j-1] + x_dot[j-1] * (t[j] - t[j-1])
    X_data[i*len(t):(i+1)*len(t),:] = x
    X_dot_data[i*len(t):(i+1)*len(t),:] = x_dot
    plt.plot(x[:, 0], x[:, 1])

# Plotting the origin
plt.plot(0, 0, 'ro')
plt.text(0.1, 0.1, 'Origin (0, 0)', fontsize=10)

plt.xlabel('x')
plt.ylabel('y')
plt.title('100 Trajectories of the Linear Dynamical System')
plt.grid(True)
plt.axis('equal')
plt.show()

# %%
Q = np.eye(2)
# Defining the Lyapunov Function for the Trajectories
P = solve_continuous_lyapunov(A.T, -Q)
P = torch.tensor(P, dtype=torch.float32)
A = torch.tensor(A, dtype=torch.float32)

# %% [markdown]
# ## Neural Network

# %%
## NN for learning the Lyapunov Function
class Net(torch.nn.Module):
    def __init__(self,n_input,n_hidden,n_output):
        super(Net, self).__init__()
        self.layer1 = torch.nn.Linear(n_input, n_hidden)
        self.layer2 = torch.nn.Linear(n_hidden,n_output)
        # Xavier Initialisation
        nn.init.xavier_uniform_(self.layer1.weight)
        nn.init.xavier_uniform_(self.layer2.weight)
    def forward(self,x):
        sigmoid = torch.nn.Tanh()
        h_1 = sigmoid(self.layer1(x))
        out = sigmoid(self.layer2(h_1))
        return out

# %%
# NN for learning dynamics
class fNet(torch.nn.Module):
    def __init__(self,n_input, n_hidden1,  n_output):
        super().__init__()
        self.layer1 = torch.nn.Linear(n_input, n_hidden1)
        self.layer2 = torch.nn.Linear(n_hidden1,n_output)  
        # Xavier Initialisation
        nn.init.xavier_uniform_(self.layer1.weight)
        nn.init.xavier_uniform_(self.layer2.weight)
    def forward(self,x):
        sigmoid = torch.nn.Tanh()
        h_1 = sigmoid(self.layer1(x))
        out = self.layer2(h_1) 
        return out

# %% [markdown]
# ## Helper Functions

# %%
# Given a dynamical system dx/dt = f(x,u) and candidate Lyapunov function V
# Check the Lyapunov conditions within a domain around the origin (ball_lb ≤ sqrt(∑xᵢ²) ≤ ball_ub). 
# If it return unsat, then there is no state violating the conditions. 
def CheckLyapunov(x, f, V, ball_lb, ball_ub, config, epsilon):    
    ball= Expression(0)
    lie_derivative_of_V = Expression(0)
    
    for i in range(len(x)):
        ball += x[i]*x[i]
        lie_derivative_of_V += f[i]*V.Differentiate(x[i])  
    ball_in_bound = logical_and(ball_lb*ball_lb <= ball, ball <= ball_ub*ball_ub)
    
    # Constraint: x ∈ Ball → (V(c, x) > 0 ∧ Lie derivative of V <= 0)     
    condition = logical_and(logical_imply(ball_in_bound, V >= 0),
                           logical_imply(ball_in_bound, lie_derivative_of_V <= epsilon))
    # Constraint: x^2 < lb → (V(x) = 0)
    # V_epsi = 1e-3
    # ball_in_bound_internal = logical_and(0 <= ball, ball <= ball_lb*ball_lb)
    # condition_y = logical_and(logical_imply(ball_in_bound_internal, V <= V_epsi), condition)
    return CheckSatisfiability(logical_not(condition),config)

# Given a candidate Lyapunov function V, check the Lipschitz constant within a domain around the origin (sqrt(∑xᵢ²) ≤ ball_ub). 
# If it return unsat, then there is no state violating the conditions. 
def CheckdVdx(x, V, ball_ub, config, M):        
    ball= Expression(0)
    derivative_of_V = Expression(0)
    
    for i in range(len(x)):
        ball += x[i]*x[i]
        derivative_of_V += V.Differentiate(x[i])*V.Differentiate(x[i])
    ball_in_bound = logical_and(ball <= ball_ub*ball_ub)
    
    # Constraint: x ∈ Ball → partial derivative of V <= M     
    condition = logical_imply(ball_in_bound, derivative_of_V <= M)
    return CheckSatisfiability(logical_not(condition),config)

# Adding Counter-Examples back to sample set
def AddCounterexamples(x,CE,N): 
    c = []
    nearby= []
    for i in range(CE.size()):
        c.append(CE[i].mid())
        lb = CE[i].lb()
        ub = CE[i].ub()
        nearby_ = np.random.uniform(lb,ub,N)
        nearby.append(nearby_)
    for i in range(N):
        n_pt = []
        for j in range(x.shape[1]):
            n_pt.append(nearby[j][i])             
        x = torch.cat((x, torch.tensor([n_pt])), 0)
    return x

# Derivative of activation
def dtanh(s):
    return 1.0 - s**2

# Circle function values
def Tune(x):
    y = []
    for r in range(0,len(x)):
        v = 0 
        for j in range(x.shape[1]):
            v += x[r][j]**2
        f = [torch.sqrt(v)]
        y.append(f)
    y = torch.tensor(y)
    return y

# Loss Function for Warmstarting
def lossfunction_warm(x, y, model_v, model_f):
    # V_candidate = model_v(x)
    y_pred = model_f(x)
    # Circle_Tuning = Tune(x)
    # Circle_Tuning = Circle_Tuning
    loss_fn = nn.MSELoss()  # mean square error
    L1 = loss_fn(y_pred, y)
    #loss = ((Circle_Tuning-V_candidate).pow(2)).mean() + 10 * L1
    loss = L1
    return loss

# %%
################ WARM STARTING #############
# Neural Network Structure
nn_h_f = 50
# Dimensions
nn_x = 2
# Weights for the LOSS
DECAY_MSE = 1
DECAY_LY = 1
DECAY_LYG = 1
# Epochs
n_epochs = 100
lr_warm = 0.005
########################### TRAINING SET ############################################################
X_train, X_test, y_train, y_test = train_test_split(X_data, X_dot_data, train_size=0.2, shuffle=False)
# Convert to 2D PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

########################## Improving V ################################################
'''
For learning the Lyapunov Function and Dynamics Function together
'''
N = 1000            # sample size
D_in = 2           # input dimension
H1 = 10            # hidden dimension
D_out = 1          # output dimension
x = torch.Tensor(N, D_in).uniform_(region[0],region[1])           
x_0 = torch.zeros([1, 2])
'''
For verifying 
'''
x1 = Variable("x1")
x2 = Variable("x2")
vars_ = [x1,x2]
config = Config()
config.use_polytope_in_forall = True
config.use_local_optimization = True
config.precision = 1e-2

learning_rate = 0.0001
# For Verification
beta = -0.02 # initial guess of beta
# Checking candidate V within a ball around the origin (ball_lb ≤ sqrt(∑xᵢ²) ≤ ball_ub)
ball_lb = 1e-4
ball_ub = 2

# parameters for beta
Kf = 3.4599
KF = 5.452
d = 5e-4
loss = 0.0085 # equals alpha above

# %%
# Hold the best model
best_mse = np.inf   # init to infinity
best_weights = None
history = []

# Model
model_f = fNet(nn_x, nn_h_f, nn_x)
model_v = Net(D_in,H1, D_out)

loss_fn = nn.MSELoss()  # mean square error
optimizer_f = torch.optim.Adam(model_f.parameters(), lr = lr_warm)
optimizer_v = torch.optim.Adam(model_v.parameters(), lr = lr_warm)

for epoch in range(n_epochs):
    model_f.train()
    model_v.train()
    # Calculate the loss
    loss = lossfunction_warm(X_train, y_train, model_v, model_f)
    # backward pass
    optimizer_f.zero_grad()
    optimizer_v.zero_grad()
    loss.backward() 
    optimizer_f.step()
    optimizer_v.step()
    #evaluate accuracy at end of each epoch
    model_f.eval()
    model_v.eval()
    y_pred = model_f(X_test)
    mse = lossfunction_warm(X_test, y_test, model_v, model_f)
    mse = float(mse)
    history.append(mse)
    if loss < best_mse:
        best_mse = mse
        best_weights = copy.deepcopy(model_f.state_dict())
    with torch.no_grad():
        torch.cuda.empty_cache()
# restore model and return best accuracy
model_f.load_state_dict(best_weights)
print("MSE: %.4f" % best_mse)
print("RMSE: %.4f" % np.sqrt(best_mse))
plt.plot(history)
plt.show()
model_f.eval()
# Out:
# /home/allemmbinn/miniconda3/lib/python3.11/site-packages/torch/autograd/graph.py:744: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# MSE: 0.0033
# RMSE: 0.0574
# fNet(
#   (layer1): Linear(in_features=2, out_features=50, bias=True)
#   (layer2): Linear(in_features=50, out_features=2, bias=True)
# )

# %% [markdown]
# ## Taking Train Dataset Whole

# %%
out_iters = 0
valid = False
while out_iters < 2 and not valid: 
    start = timeit.default_timer()
    model_v = Net(D_in,H1, D_out)
    L = []
    i = 0 
    t = 0
    max_iters = 5000 # increase number of epoches if cannot find a valid LF
    optimizer_v = torch.optim.Adam(model_v.parameters(), lr=learning_rate)

    while i < max_iters and not valid: 
        # Calculate the loss
        x = x.float()
        x = x
        # Value of Lyapunov Model
        V_candidate = model_v(x)
        X0 = model_v(x_0)
        # Value of Function Model
        f = model_f(x)
        Circle_Tuning = Tune(x)
        Circle_Tuning = Circle_Tuning
        # Compute lie derivative of V : L_V = ∑∂V/∂xᵢ*fᵢ
        L_V = torch.diagonal(torch.mm(torch.mm(torch.mm(dtanh(V_candidate),model_v.layer2.weight)\
                            *dtanh(torch.tanh(torch.mm(x,model_v.layer1.weight.t())+model_v.layer1.bias)),model_v.layer1.weight),f.t()),0)
        
        dVdx = torch.mm(torch.mm(dtanh(V_candidate),model_v.layer2.weight)\
                            *dtanh(torch.tanh(torch.mm(x,model_v.layer1.weight.t())+model_v.layer1.bias)),model_v.layer1.weight)
                
        # MSE Loss
        L1 = loss_fn(model_f(X_train),y_train)
                
        # Needs to be tuned
        Lyapunov_risk = (F.relu(-V_candidate)+ 1.2 * F.relu(L_V+0.2)).mean() +((Circle_Tuning-V_candidate).pow(2)).mean() + 5*(X0).pow(2) + 0.01*torch.norm(dVdx) + 3 * L1
 
        L.append(Lyapunov_risk.item())
        optimizer_v.zero_grad()
        optimizer_f.zero_grad()
        Lyapunov_risk.backward()
        optimizer_v.step() 
        optimizer_f.step() 

        print(f"{i}) Lyapunov Risk = {Lyapunov_risk.item()}, MSE = {L1}, V_0_loss = {(X0).pow(2).float()}, V_pos_loss = {F.relu(-V_candidate).mean()}, Lv_loss = {F.relu(L_V).mean()}, Circular Tuning Loss = {((Circle_Tuning-V_candidate).pow(2)).mean()}")
        # Finding the values for the new model function
        f_w1 = model_f.layer1.weight.data.cpu().numpy()
        f_w2 = model_f.layer2.weight.data.cpu().numpy()
        f_b1 = model_f.layer1.bias.data.cpu().numpy()
        f_b2 = model_f.layer2.bias.data.cpu().numpy()

        f_h1 = []
        f_z1 = np.dot(vars_,f_w1.T)+f_b1
        for n in range(len(f_z1)):
            f_h1.append(tanh(f_z1[n]))
        f_learn = np.dot(f_h1,f_w2.T)+f_b2
        # save the weights and biases 
        w1 = model_v.layer1.weight.data.cpu().numpy()
        w2 = model_v.layer2.weight.data.cpu().numpy()
        b1 = model_v.layer1.bias.data.cpu().numpy()
        b2 = model_v.layer2.bias.data.cpu().numpy()
        
        # Falsification with SMT solver
        if i % 10 == 0:
                    
            # Candidate V
            z1 = np.dot(vars_,w1.T)+b1
        
            a1 = []
            for j in range(0,len(z1)):
                a1.append(tanh(z1[j]))
            z2 = np.dot(a1,w2.T)+b2
            V_learn = tanh(z2.item(0))
        
            print('===========Verifying==========')        
            start_ = timeit.default_timer() 
            beta = -np.maximum(beta, -0.02) # in case beta is too negative and cannot return any results
            result= CheckLyapunov(vars_, f_learn, V_learn, ball_lb, ball_ub, config, beta) # SMT solver
            stop_ = timeit.default_timer() 
        
            if (result): 
                    print("Not a Lyapunov function. Found counterexample: ")
                    print(result)
                    x = x.to('cpu')
                    x = AddCounterexamples(x,result,10)
            else:  
                    # # calculate norm of dVdx with the SMT solver
                    # M = 0.05 # lower bound of M
                    # dvdx_bound = np.sqrt(M)
                    # violation = CheckdVdx(vars_, V_learn, ball_ub, config, M) 
                    # while violation:
                    #     violation = CheckdVdx(vars_, V_learn, ball_ub, config, M)
                    #     if not violation:
                    #         dvdx_bound = np.sqrt(M)
                    #         print(dvdx_bound, "is the norm of dVdx")
                    #     M += 0.001
                    # beta = -dvdx_bound*((Kf+KF)*d+loss) # update beta 
                    # print("Satisfies with a non-strict condition")
                    # result_strict= CheckLyapunov(vars_, f_learn, V_learn, ball_lb, ball_ub, config, beta) # SMT solver
                    # beta = beta.detach().numpy()
                    # if not result_strict:
                    #     valid = True
                    #     print("Satisfy conditions with beta = ", beta)
                    #     print(V_learn, " is a Lyapunov function.")
                    valid = True
                    print("Satisfy conditions")
                    print(V_learn, " is a Lyapunov function.")
            t += (stop_ - start_)
            print('==============================') 
        i += 1

    stop = timeit.default_timer()
    
    np.savetxt("w1_vdp.txt", model_v.layer1.weight.data.cpu(), fmt="%s")
    np.savetxt("w2_vdp.txt", model_v.layer2.weight.data.cpu(), fmt="%s")
    np.savetxt("b1_vdp.txt", model_v.layer1.bias.data.cpu(), fmt="%s")
    np.savetxt("b2_vdp.txt", model_v.layer2.bias.data.cpu(), fmt="%s")

    print('\n')
    print("Total time: ", stop - start)
    print("Verified time: ", t)
    
    out_iters+=1
# Out:
# 0) Lyapunov Risk = 0.9496384263038635, MSE = 0.0032376034650951624, V_0_loss = tensor([[0.0380]], grad_fn=<PowBackward0>), V_pos_loss = 0.014363938011229038, Lv_loss = 0.02104780077934265, Circular Tuning Loss = 0.413663387298584
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-1.9995879702531847, -1.9976749043558231]
# x2 : [0.040594940802395563, 0.043977852535928529]
# ==============================
# 1) Lyapunov Risk = 0.955305814743042, MSE = 0.005116734653711319, V_0_loss = tensor([[0.0378]], grad_fn=<PowBackward0>), V_pos_loss = 0.014272648841142654, Lv_loss = 0.017678722739219666, Circular Tuning Loss = 0.42810529470443726
# 2) Lyapunov Risk = 0.9518946409225464, MSE = 0.009113108739256859, V_0_loss = tensor([[0.0375]], grad_fn=<PowBackward0>), V_pos_loss = 0.014323854818940163, Lv_loss = 0.01470605656504631, Circular Tuning Loss = 0.42861974239349365
# 3) Lyapunov Risk = 0.9422604441642761, MSE = 0.00873203482478857, V_0_loss = tensor([[0.0373]], grad_fn=<PowBackward0>), V_pos_loss = 0.014375965110957623, Lv_loss = 0.01391600351780653, Circular Tuning Loss = 0.42913535237312317
# 4) Lyapunov Risk = 0.9363372325897217, MSE = 0.008586634881794453, V_0_loss = tensor([[0.0371]], grad_fn=<PowBackward0>), V_pos_loss = 0.014428475871682167, Lv_loss = 0.014017992652952671, Circular Tuning Loss = 0.4296521842479706
# 5) Lyapunov Risk = 0.9368712902069092, MSE = 0.01151860412210226, V_0_loss = tensor([[0.0369]], grad_fn=<PowBackward0>), V_pos_loss = 0.01448147650808096, Lv_loss = 0.013651273213326931, Circular Tuning Loss = 0.430170476436615
# 6) Lyapunov Risk = 0.9352701902389526, MSE = 0.015333464369177818, V_0_loss = tensor([[0.0366]], grad_fn=<PowBackward0>), V_pos_loss = 0.014535609632730484, Lv_loss = 0.01251937635242939, Circular Tuning Loss = 0.4306906461715698
# 7) Lyapunov Risk = 0.9347730875015259, MSE = 0.019756436347961426, V_0_loss = tensor([[0.0364]], grad_fn=<PowBackward0>), V_pos_loss = 0.014590373262763023, Lv_loss = 0.011468731798231602, Circular Tuning Loss = 0.43121275305747986
# 8) Lyapunov Risk = 0.9366596341133118, MSE = 0.023103555664420128, V_0_loss = tensor([[0.0362]], grad_fn=<PowBackward0>), V_pos_loss = 0.014645585790276527, Lv_loss = 0.011353548616170883, Circular Tuning Loss = 0.43173617124557495
# 9) Lyapunov Risk = 0.9341676831245422, MSE = 0.022213872522115707, V_0_loss = tensor([[0.0360]], grad_fn=<PowBackward0>), V_pos_loss = 0.014701299369335175, Lv_loss = 0.012567195110023022, Circular Tuning Loss = 0.4322597086429596
# 10) Lyapunov Risk = 0.9293572306632996, MSE = 0.018563171848654747, V_0_loss = tensor([[0.0358]], grad_fn=<PowBackward0>), V_pos_loss = 0.01475734356790781, Lv_loss = 0.01494360901415348, Circular Tuning Loss = 0.4327827990055084
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-1.9986147851875593, -1.9967961946642689]
# x2 : [-0.077806969871258166, -0.074424058137725208]
# ==============================
# 11) Lyapunov Risk = 0.940712571144104, MSE = 0.014906886033713818, V_0_loss = tensor([[0.0356]], grad_fn=<PowBackward0>), V_pos_loss = 0.014668028801679611, Lv_loss = 0.01762932352721691, Circular Tuning Loss = 0.4472503066062927
# 12) Lyapunov Risk = 0.9370120167732239, MSE = 0.01176456455141306, V_0_loss = tensor([[0.0353]], grad_fn=<PowBackward0>), V_pos_loss = 0.014723450876772404, Lv_loss = 0.020094625651836395, Circular Tuning Loss = 0.44777679443359375
# 13) Lyapunov Risk = 0.9333351254463196, MSE = 0.009529126808047295, V_0_loss = tensor([[0.0351]], grad_fn=<PowBackward0>), V_pos_loss = 0.014778458513319492, Lv_loss = 0.021861393004655838, Circular Tuning Loss = 0.4483025372028351
# 14) Lyapunov Risk = 0.9327229261398315, MSE = 0.008671686053276062, V_0_loss = tensor([[0.0349]], grad_fn=<PowBackward0>), V_pos_loss = 0.014833103865385056, Lv_loss = 0.023273590952157974, Circular Tuning Loss = 0.4488268494606018
# 15) Lyapunov Risk = 0.9333235025405884, MSE = 0.00793000590056181, V_0_loss = tensor([[0.0347]], grad_fn=<PowBackward0>), V_pos_loss = 0.014887735247612, Lv_loss = 0.024914508685469627, Circular Tuning Loss = 0.44934916496276855
# 16) Lyapunov Risk = 0.9325907230377197, MSE = 0.006405889987945557, V_0_loss = tensor([[0.0345]], grad_fn=<PowBackward0>), V_pos_loss = 0.01494165975600481, Lv_loss = 0.026853682473301888, Circular Tuning Loss = 0.4498690962791443
# 17) Lyapunov Risk = 0.931668221950531, MSE = 0.0050864554941654205, V_0_loss = tensor([[0.0343]], grad_fn=<PowBackward0>), V_pos_loss = 0.014995039440691471, Lv_loss = 0.02855110354721546, Circular Tuning Loss = 0.450386643409729
# 18) Lyapunov Risk = 0.9306333065032959, MSE = 0.004775319714099169, V_0_loss = tensor([[0.0341]], grad_fn=<PowBackward0>), V_pos_loss = 0.015047778375446796, Lv_loss = 0.029181746765971184, Circular Tuning Loss = 0.4509020149707794
# 19) Lyapunov Risk = 0.9280617237091064, MSE = 0.005318143405020237, V_0_loss = tensor([[0.0339]], grad_fn=<PowBackward0>), V_pos_loss = 0.015099707990884781, Lv_loss = 0.028378542512655258, Circular Tuning Loss = 0.45141521096229553
# 20) Lyapunov Risk = 0.9251421689987183, MSE = 0.006674368400126696, V_0_loss = tensor([[0.0337]], grad_fn=<PowBackward0>), V_pos_loss = 0.01515084970742464, Lv_loss = 0.026562854647636414, Circular Tuning Loss = 0.45192593336105347
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [0.24609375000000006, 0.25000000000000006]
# x2 : [0.12500000000000003, 0.12890625000000006]
# ==============================
# 21) Lyapunov Risk = 0.9207104444503784, MSE = 0.008539046160876751, V_0_loss = tensor([[0.0335]], grad_fn=<PowBackward0>), V_pos_loss = 0.015053686685860157, Lv_loss = 0.02449166029691696, Circular Tuning Loss = 0.44829490780830383
# 22) Lyapunov Risk = 0.9192906618118286, MSE = 0.009967725723981857, V_0_loss = tensor([[0.0333]], grad_fn=<PowBackward0>), V_pos_loss = 0.015103355050086975, Lv_loss = 0.02289336919784546, Circular Tuning Loss = 0.4487972557544708
# 23) Lyapunov Risk = 0.9177827835083008, MSE = 0.010616275481879711, V_0_loss = tensor([[0.0331]], grad_fn=<PowBackward0>), V_pos_loss = 0.015152753330767155, Lv_loss = 0.021897602826356888, Circular Tuning Loss = 0.44929713010787964
# 24) Lyapunov Risk = 0.9168088436126709, MSE = 0.010926008224487305, V_0_loss = tensor([[0.0329]], grad_fn=<PowBackward0>), V_pos_loss = 0.015201610513031483, Lv_loss = 0.021256262436509132, Circular Tuning Loss = 0.4497939348220825
# 25) Lyapunov Risk = 0.9158518314361572, MSE = 0.011157708242535591, V_0_loss = tensor([[0.0327]], grad_fn=<PowBackward0>), V_pos_loss = 0.015250029973685741, Lv_loss = 0.020579172298312187, Circular Tuning Loss = 0.4502885043621063
# 26) Lyapunov Risk = 0.9140263795852661, MSE = 0.011223246343433857, V_0_loss = tensor([[0.0325]], grad_fn=<PowBackward0>), V_pos_loss = 0.015298213809728622, Lv_loss = 0.019699838012456894, Circular Tuning Loss = 0.4507814347743988
# 27) Lyapunov Risk = 0.9119750261306763, MSE = 0.011156892403960228, V_0_loss = tensor([[0.0323]], grad_fn=<PowBackward0>), V_pos_loss = 0.015346551313996315, Lv_loss = 0.01880216784775257, Circular Tuning Loss = 0.4512729048728943
# 28) Lyapunov Risk = 0.9102595448493958, MSE = 0.010802538134157658, V_0_loss = tensor([[0.0321]], grad_fn=<PowBackward0>), V_pos_loss = 0.015395157970488071, Lv_loss = 0.018205275759100914, Circular Tuning Loss = 0.4517631232738495
# 29) Lyapunov Risk = 0.9084861874580383, MSE = 0.009835554286837578, V_0_loss = tensor([[0.0319]], grad_fn=<PowBackward0>), V_pos_loss = 0.015444100834429264, Lv_loss = 0.018073687329888344, Circular Tuning Loss = 0.4522518515586853
# 30) Lyapunov Risk = 0.9068313837051392, MSE = 0.008478155359625816, V_0_loss = tensor([[0.0317]], grad_fn=<PowBackward0>), V_pos_loss = 0.015492880716919899, Lv_loss = 0.018290294334292412, Circular Tuning Loss = 0.45273932814598083
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.0039062500000000009, 0]
# x2 : [-0.73046875000000022, -0.72656250000000022]
# ==============================
# 31) Lyapunov Risk = 0.906521737575531, MSE = 0.0073718964122235775, V_0_loss = tensor([[0.0315]], grad_fn=<PowBackward0>), V_pos_loss = 0.01539219543337822, Lv_loss = 0.01832619495689869, Circular Tuning Loss = 0.452911913394928
# 32) Lyapunov Risk = 0.9054432511329651, MSE = 0.0068305479362607, V_0_loss = tensor([[0.0313]], grad_fn=<PowBackward0>), V_pos_loss = 0.015440452843904495, Lv_loss = 0.018168780952692032, Circular Tuning Loss = 0.45339810848236084
# 33) Lyapunov Risk = 0.9040042161941528, MSE = 0.006857200060039759, V_0_loss = tensor([[0.0312]], grad_fn=<PowBackward0>), V_pos_loss = 0.015488787554204464, Lv_loss = 0.017562583088874817, Circular Tuning Loss = 0.4538841247558594
# 34) Lyapunov Risk = 0.9025338292121887, MSE = 0.0073187341913580894, V_0_loss = tensor([[0.0310]], grad_fn=<PowBackward0>), V_pos_loss = 0.015537476167082787, Lv_loss = 0.01671528071165085, Circular Tuning Loss = 0.45436975359916687
# 35) Lyapunov Risk = 0.9010881781578064, MSE = 0.007832187227904797, V_0_loss = tensor([[0.0308]], grad_fn=<PowBackward0>), V_pos_loss = 0.015586323104798794, Lv_loss = 0.015933802351355553, Circular Tuning Loss = 0.45485398173332214
# 36) Lyapunov Risk = 0.8995368480682373, MSE = 0.008082548156380653, V_0_loss = tensor([[0.0306]], grad_fn=<PowBackward0>), V_pos_loss = 0.015635086223483086, Lv_loss = 0.015397966839373112, Circular Tuning Loss = 0.45533546805381775
# 37) Lyapunov Risk = 0.8981518149375916, MSE = 0.008183890022337437, V_0_loss = tensor([[0.0304]], grad_fn=<PowBackward0>), V_pos_loss = 0.015683205798268318, Lv_loss = 0.015057560987770557, Circular Tuning Loss = 0.45581260323524475
# 38) Lyapunov Risk = 0.8970567584037781, MSE = 0.008378516882658005, V_0_loss = tensor([[0.0303]], grad_fn=<PowBackward0>), V_pos_loss = 0.01573033258318901, Lv_loss = 0.014730128459632397, Circular Tuning Loss = 0.45628416538238525
# 39) Lyapunov Risk = 0.8958734273910522, MSE = 0.008698082529008389, V_0_loss = tensor([[0.0301]], grad_fn=<PowBackward0>), V_pos_loss = 0.01577639952301979, Lv_loss = 0.014289290644228458, Circular Tuning Loss = 0.4567496180534363
# 40) Lyapunov Risk = 0.8945067524909973, MSE = 0.009064765647053719, V_0_loss = tensor([[0.0299]], grad_fn=<PowBackward0>), V_pos_loss = 0.015821468085050583, Lv_loss = 0.013781452551484108, Circular Tuning Loss = 0.4572092294692993
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [0.24609375000000006, 0.25000000000000006]
# x2 : [0.031250000000000007, 0.035156250000000014]
# ==============================
# 41) Lyapunov Risk = 0.8906810879707336, MSE = 0.009318208321928978, V_0_loss = tensor([[0.0297]], grad_fn=<PowBackward0>), V_pos_loss = 0.015714505687355995, Lv_loss = 0.013419505208730698, Circular Tuning Loss = 0.45354142785072327
# 42) Lyapunov Risk = 0.8893301486968994, MSE = 0.009233041666448116, V_0_loss = tensor([[0.0296]], grad_fn=<PowBackward0>), V_pos_loss = 0.015757516026496887, Lv_loss = 0.013276075012981892, Circular Tuning Loss = 0.45398765802383423
# 43) Lyapunov Risk = 0.8879613876342773, MSE = 0.008775117807090282, V_0_loss = tensor([[0.0294]], grad_fn=<PowBackward0>), V_pos_loss = 0.01580043137073517, Lv_loss = 0.013408252038061619, Circular Tuning Loss = 0.45443007349967957
# 44) Lyapunov Risk = 0.8867449760437012, MSE = 0.008222094736993313, V_0_loss = tensor([[0.0292]], grad_fn=<PowBackward0>), V_pos_loss = 0.01584327220916748, Lv_loss = 0.013670047745108604, Circular Tuning Loss = 0.45487073063850403
# 45) Lyapunov Risk = 0.8856037259101868, MSE = 0.007817907258868217, V_0_loss = tensor([[0.0291]], grad_fn=<PowBackward0>), V_pos_loss = 0.01588623598217964, Lv_loss = 0.013876168057322502, Circular Tuning Loss = 0.45531022548675537
# 46) Lyapunov Risk = 0.8843945860862732, MSE = 0.007648158352822065, V_0_loss = tensor([[0.0289]], grad_fn=<PowBackward0>), V_pos_loss = 0.01592901162803173, Lv_loss = 0.013924527913331985, Circular Tuning Loss = 0.4557488262653351
# 47) Lyapunov Risk = 0.8831578493118286, MSE = 0.0076678055338561535, V_0_loss = tensor([[0.0288]], grad_fn=<PowBackward0>), V_pos_loss = 0.01597154326736927, Lv_loss = 0.01385193970054388, Circular Tuning Loss = 0.45618611574172974
# 48) Lyapunov Risk = 0.881924033164978, MSE = 0.007725668139755726, V_0_loss = tensor([[0.0286]], grad_fn=<PowBackward0>), V_pos_loss = 0.016013750806450844, Lv_loss = 0.013770227320492268, Circular Tuning Loss = 0.4566216468811035
# 49) Lyapunov Risk = 0.8806592226028442, MSE = 0.0076788985170423985, V_0_loss = tensor([[0.0284]], grad_fn=<PowBackward0>), V_pos_loss = 0.016055483371019363, Lv_loss = 0.0137602798640728, Circular Tuning Loss = 0.4570547342300415
# 50) Lyapunov Risk = 0.8794381022453308, MSE = 0.0075286622159183025, V_0_loss = tensor([[0.0283]], grad_fn=<PowBackward0>), V_pos_loss = 0.016096405684947968, Lv_loss = 0.01381070539355278, Circular Tuning Loss = 0.4574835002422333
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.0039062500000000009, 0]
# x2 : [-0.46093750000000011, -0.45703125000000011]
# ==============================
# 51) Lyapunov Risk = 0.876381516456604, MSE = 0.0074024079367518425, V_0_loss = tensor([[0.0281]], grad_fn=<PowBackward0>), V_pos_loss = 0.015984348952770233, Lv_loss = 0.013699367642402649, Circular Tuning Loss = 0.45475220680236816
# 52) Lyapunov Risk = 0.8752369284629822, MSE = 0.007410653866827488, V_0_loss = tensor([[0.0280]], grad_fn=<PowBackward0>), V_pos_loss = 0.016023168340325356, Lv_loss = 0.013566999696195126, Circular Tuning Loss = 0.4551687240600586
# 53) Lyapunov Risk = 0.8740618228912354, MSE = 0.00753795076161623, V_0_loss = tensor([[0.0278]], grad_fn=<PowBackward0>), V_pos_loss = 0.016060980036854744, Lv_loss = 0.01328947115689516, Circular Tuning Loss = 0.4555801451206207
# 54) Lyapunov Risk = 0.8729163408279419, MSE = 0.00767882214859128, V_0_loss = tensor([[0.0277]], grad_fn=<PowBackward0>), V_pos_loss = 0.016097767278552055, Lv_loss = 0.012970571406185627, Circular Tuning Loss = 0.455986350774765
# 55) Lyapunov Risk = 0.8717724084854126, MSE = 0.00769740529358387, V_0_loss = tensor([[0.0275]], grad_fn=<PowBackward0>), V_pos_loss = 0.016133572906255722, Lv_loss = 0.012718988582491875, Circular Tuning Loss = 0.4563872516155243
# 56) Lyapunov Risk = 0.8705909848213196, MSE = 0.007549458183348179, V_0_loss = tensor([[0.0274]], grad_fn=<PowBackward0>), V_pos_loss = 0.01616845466196537, Lv_loss = 0.01256616972386837, Circular Tuning Loss = 0.45678311586380005
# 57) Lyapunov Risk = 0.8694283366203308, MSE = 0.007345263846218586, V_0_loss = tensor([[0.0273]], grad_fn=<PowBackward0>), V_pos_loss = 0.016202490776777267, Lv_loss = 0.012444148771464825, Circular Tuning Loss = 0.45717424154281616
# 58) Lyapunov Risk = 0.8682878017425537, MSE = 0.007203754503279924, V_0_loss = tensor([[0.0271]], grad_fn=<PowBackward0>), V_pos_loss = 0.016235703602433205, Lv_loss = 0.01226175669580698, Circular Tuning Loss = 0.4575608968734741
# 59) Lyapunov Risk = 0.867132306098938, MSE = 0.007182334084063768, V_0_loss = tensor([[0.0270]], grad_fn=<PowBackward0>), V_pos_loss = 0.016268165782094002, Lv_loss = 0.011976135894656181, Circular Tuning Loss = 0.45794352889060974
# 60) Lyapunov Risk = 0.8659923076629639, MSE = 0.0072473264299333096, V_0_loss = tensor([[0.0268]], grad_fn=<PowBackward0>), V_pos_loss = 0.01629989594221115, Lv_loss = 0.011629300191998482, Circular Tuning Loss = 0.4583218991756439
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [0.17968750000000006, 0.18359375000000006]
# x2 : [-0.027343750000000007, -0.023437500000000007]
# ==============================
# 61) Lyapunov Risk = 0.8623407483100891, MSE = 0.007310935761779547, V_0_loss = tensor([[0.0267]], grad_fn=<PowBackward0>), V_pos_loss = 0.016178322955965996, Lv_loss = 0.011351493187248707, Circular Tuning Loss = 0.45447731018066406
# 62) Lyapunov Risk = 0.8612250089645386, MSE = 0.0073112486861646175, V_0_loss = tensor([[0.0266]], grad_fn=<PowBackward0>), V_pos_loss = 0.016208847984671593, Lv_loss = 0.011076279915869236, Circular Tuning Loss = 0.4548456072807312
# 63) Lyapunov Risk = 0.8601132035255432, MSE = 0.007261523976922035, V_0_loss = tensor([[0.0265]], grad_fn=<PowBackward0>), V_pos_loss = 0.01623903587460518, Lv_loss = 0.010855581611394882, Circular Tuning Loss = 0.45521050691604614
# 64) Lyapunov Risk = 0.8590235710144043, MSE = 0.007239506579935551, V_0_loss = tensor([[0.0263]], grad_fn=<PowBackward0>), V_pos_loss = 0.016269482672214508, Lv_loss = 0.010632649064064026, Circular Tuning Loss = 0.4555719494819641
# 65) Lyapunov Risk = 0.8579381108283997, MSE = 0.007293199189007282, V_0_loss = tensor([[0.0262]], grad_fn=<PowBackward0>), V_pos_loss = 0.016299502924084663, Lv_loss = 0.010372678749263287, Circular Tuning Loss = 0.455929696559906
# 66) Lyapunov Risk = 0.8568553924560547, MSE = 0.0074062589555978775, V_0_loss = tensor([[0.0261]], grad_fn=<PowBackward0>), V_pos_loss = 0.01632891595363617, Lv_loss = 0.010084171779453754, Circular Tuning Loss = 0.4562838077545166
# 67) Lyapunov Risk = 0.8557896018028259, MSE = 0.00750035559758544, V_0_loss = tensor([[0.0260]], grad_fn=<PowBackward0>), V_pos_loss = 0.016357671469449997, Lv_loss = 0.009821713902056217, Circular Tuning Loss = 0.45663416385650635
# 68) Lyapunov Risk = 0.8547229170799255, MSE = 0.007503492757678032, V_0_loss = tensor([[0.0258]], grad_fn=<PowBackward0>), V_pos_loss = 0.016385851427912712, Lv_loss = 0.009634503163397312, Circular Tuning Loss = 0.45698079466819763
# 69) Lyapunov Risk = 0.8536504507064819, MSE = 0.00740760937333107, V_0_loss = tensor([[0.0257]], grad_fn=<PowBackward0>), V_pos_loss = 0.016413504257798195, Lv_loss = 0.009520726278424263, Circular Tuning Loss = 0.45732372999191284
# 70) Lyapunov Risk = 0.8525897264480591, MSE = 0.007269334513694048, V_0_loss = tensor([[0.0256]], grad_fn=<PowBackward0>), V_pos_loss = 0.016440417617559433, Lv_loss = 0.009440070018172264, Circular Tuning Loss = 0.4576626718044281
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.0039062500000000009, 0]
# x2 : [-0.26953125000000011, -0.26562500000000011]
# ==============================
# 71) Lyapunov Risk = 0.8487978577613831, MSE = 0.007145260460674763, V_0_loss = tensor([[0.0255]], grad_fn=<PowBackward0>), V_pos_loss = 0.016314072534441948, Lv_loss = 0.009263744577765465, Circular Tuning Loss = 0.45394423604011536
# 72) Lyapunov Risk = 0.8477330207824707, MSE = 0.007071846630424261, V_0_loss = tensor([[0.0254]], grad_fn=<PowBackward0>), V_pos_loss = 0.016339324414730072, Lv_loss = 0.009128849022090435, Circular Tuning Loss = 0.45427384972572327
# 73) Lyapunov Risk = 0.8466771245002747, MSE = 0.0070227449759840965, V_0_loss = tensor([[0.0252]], grad_fn=<PowBackward0>), V_pos_loss = 0.016363926231861115, Lv_loss = 0.008973450399935246, Circular Tuning Loss = 0.45460012555122375
# 74) Lyapunov Risk = 0.8456321954727173, MSE = 0.0069593689404428005, V_0_loss = tensor([[0.0251]], grad_fn=<PowBackward0>), V_pos_loss = 0.016388002783060074, Lv_loss = 0.008831653743982315, Circular Tuning Loss = 0.4549230933189392
# 75) Lyapunov Risk = 0.8445925712585449, MSE = 0.006864483468234539, V_0_loss = tensor([[0.0250]], grad_fn=<PowBackward0>), V_pos_loss = 0.016411522403359413, Lv_loss = 0.008718175813555717, Circular Tuning Loss = 0.4552425146102905
# 76) Lyapunov Risk = 0.8435576558113098, MSE = 0.006772964261472225, V_0_loss = tensor([[0.0249]], grad_fn=<PowBackward0>), V_pos_loss = 0.016434377059340477, Lv_loss = 0.008614813908934593, Circular Tuning Loss = 0.4555583596229553
# 77) Lyapunov Risk = 0.8425224423408508, MSE = 0.006734425202012062, V_0_loss = tensor([[0.0248]], grad_fn=<PowBackward0>), V_pos_loss = 0.016456589102745056, Lv_loss = 0.008478181436657906, Circular Tuning Loss = 0.45587050914764404
# 78) Lyapunov Risk = 0.8414939641952515, MSE = 0.006754981819540262, V_0_loss = tensor([[0.0247]], grad_fn=<PowBackward0>), V_pos_loss = 0.016478147357702255, Lv_loss = 0.008299985900521278, Circular Tuning Loss = 0.4561791718006134
# 79) Lyapunov Risk = 0.8404743075370789, MSE = 0.006800977513194084, V_0_loss = tensor([[0.0246]], grad_fn=<PowBackward0>), V_pos_loss = 0.01649898663163185, Lv_loss = 0.008106747642159462, Circular Tuning Loss = 0.45648393034935
# 80) Lyapunov Risk = 0.839464008808136, MSE = 0.0068284897133708, V_0_loss = tensor([[0.0245]], grad_fn=<PowBackward0>), V_pos_loss = 0.016519255936145782, Lv_loss = 0.007931302301585674, Circular Tuning Loss = 0.45678460597991943
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [0.24218750000000006, 0.25000000000000006]
# x2 : [-0.24718750000000006, -0.23718750000000005]
# ==============================
# 81) Lyapunov Risk = 0.8369836211204529, MSE = 0.0068040406331419945, V_0_loss = tensor([[0.0244]], grad_fn=<PowBackward0>), V_pos_loss = 0.01638699322938919, Lv_loss = 0.008010270074009895, Circular Tuning Loss = 0.45372357964515686
# 82) Lyapunov Risk = 0.8359736800193787, MSE = 0.0067603010684251785, V_0_loss = tensor([[0.0243]], grad_fn=<PowBackward0>), V_pos_loss = 0.016405750066041946, Lv_loss = 0.007883076556026936, Circular Tuning Loss = 0.45401501655578613
# 83) Lyapunov Risk = 0.8349677324295044, MSE = 0.006720697972923517, V_0_loss = tensor([[0.0242]], grad_fn=<PowBackward0>), V_pos_loss = 0.01642376370728016, Lv_loss = 0.007741792593151331, Circular Tuning Loss = 0.454302579164505
# 84) Lyapunov Risk = 0.8339653015136719, MSE = 0.006692542228847742, V_0_loss = tensor([[0.0241]], grad_fn=<PowBackward0>), V_pos_loss = 0.016441062092781067, Lv_loss = 0.0075800432823598385, Circular Tuning Loss = 0.45458635687828064
# 85) Lyapunov Risk = 0.8329678177833557, MSE = 0.006660641636699438, V_0_loss = tensor([[0.0240]], grad_fn=<PowBackward0>), V_pos_loss = 0.016457578167319298, Lv_loss = 0.007413558661937714, Circular Tuning Loss = 0.45486611127853394
# 86) Lyapunov Risk = 0.8319762945175171, MSE = 0.006613492034375668, V_0_loss = tensor([[0.0239]], grad_fn=<PowBackward0>), V_pos_loss = 0.016473282128572464, Lv_loss = 0.007251922506839037, Circular Tuning Loss = 0.45514190196990967
# 87) Lyapunov Risk = 0.8309888243675232, MSE = 0.006540743168443441, V_0_loss = tensor([[0.0238]], grad_fn=<PowBackward0>), V_pos_loss = 0.016488242894411087, Lv_loss = 0.007103554904460907, Circular Tuning Loss = 0.45541366934776306
# 88) Lyapunov Risk = 0.8300024271011353, MSE = 0.006466316059231758, V_0_loss = tensor([[0.0237]], grad_fn=<PowBackward0>), V_pos_loss = 0.016502423211932182, Lv_loss = 0.0069533153437078, Circular Tuning Loss = 0.45568135380744934
# 89) Lyapunov Risk = 0.829018771648407, MSE = 0.006418339442461729, V_0_loss = tensor([[0.0236]], grad_fn=<PowBackward0>), V_pos_loss = 0.016515817493200302, Lv_loss = 0.006783046294003725, Circular Tuning Loss = 0.45594513416290283
# 90) Lyapunov Risk = 0.828034520149231, MSE = 0.006400264799594879, V_0_loss = tensor([[0.0235]], grad_fn=<PowBackward0>), V_pos_loss = 0.016528433188796043, Lv_loss = 0.006590203382074833, Circular Tuning Loss = 0.45620498061180115
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.0039062500000000009, 0]
# x2 : [0, 0.0039062500000000009]
# ==============================
# 91) Lyapunov Risk = 0.8245107531547546, MSE = 0.006402796134352684, V_0_loss = tensor([[0.0234]], grad_fn=<PowBackward0>), V_pos_loss = 0.016389982774853706, Lv_loss = 0.00632509496062994, Circular Tuning Loss = 0.4525180757045746
# 92) Lyapunov Risk = 0.8235348463058472, MSE = 0.006417582742869854, V_0_loss = tensor([[0.0233]], grad_fn=<PowBackward0>), V_pos_loss = 0.016401484608650208, Lv_loss = 0.006115209776908159, Circular Tuning Loss = 0.45276862382888794
# 93) Lyapunov Risk = 0.8225562572479248, MSE = 0.006427163723856211, V_0_loss = tensor([[0.0233]], grad_fn=<PowBackward0>), V_pos_loss = 0.016412541270256042, Lv_loss = 0.0059170955792069435, Circular Tuning Loss = 0.45301684737205505
# 94) Lyapunov Risk = 0.8215796947479248, MSE = 0.006432814057916403, V_0_loss = tensor([[0.0232]], grad_fn=<PowBackward0>), V_pos_loss = 0.01642315834760666, Lv_loss = 0.005727539770305157, Circular Tuning Loss = 0.453262597322464
# 95) Lyapunov Risk = 0.8206065893173218, MSE = 0.006439198274165392, V_0_loss = tensor([[0.0231]], grad_fn=<PowBackward0>), V_pos_loss = 0.016433296725153923, Lv_loss = 0.005540798418223858, Circular Tuning Loss = 0.45350563526153564
# 96) Lyapunov Risk = 0.819634199142456, MSE = 0.006446894258260727, V_0_loss = tensor([[0.0230]], grad_fn=<PowBackward0>), V_pos_loss = 0.01644296944141388, Lv_loss = 0.005353917833417654, Circular Tuning Loss = 0.4537459909915924
# 97) Lyapunov Risk = 0.8186696767807007, MSE = 0.00644721370190382, V_0_loss = tensor([[0.0229]], grad_fn=<PowBackward0>), V_pos_loss = 0.01645226590335369, Lv_loss = 0.005183061584830284, Circular Tuning Loss = 0.4539835751056671
# 98) Lyapunov Risk = 0.817708432674408, MSE = 0.0064187441021203995, V_0_loss = tensor([[0.0228]], grad_fn=<PowBackward0>), V_pos_loss = 0.016461076214909554, Lv_loss = 0.005036493297666311, Circular Tuning Loss = 0.4542180299758911
# 99) Lyapunov Risk = 0.8167479038238525, MSE = 0.006362373940646648, V_0_loss = tensor([[0.0228]], grad_fn=<PowBackward0>), V_pos_loss = 0.016469324007630348, Lv_loss = 0.004914219956845045, Circular Tuning Loss = 0.45444929599761963
# 100) Lyapunov Risk = 0.8157859444618225, MSE = 0.00629478320479393, V_0_loss = tensor([[0.0227]], grad_fn=<PowBackward0>), V_pos_loss = 0.01647702232003212, Lv_loss = 0.004805902950465679, Circular Tuning Loss = 0.4546772241592407
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [0.52734375000000022, 0.53125000000000022]
# x2 : [0.18750000000000006, 0.19140625000000006]
# ==============================
# 101) Lyapunov Risk = 0.815144419670105, MSE = 0.006236706860363483, V_0_loss = tensor([[0.0226]], grad_fn=<PowBackward0>), V_pos_loss = 0.016335928812623024, Lv_loss = 0.004816587548702955, Circular Tuning Loss = 0.4535258114337921
# 102) Lyapunov Risk = 0.814182698726654, MSE = 0.006215305533260107, V_0_loss = tensor([[0.0225]], grad_fn=<PowBackward0>), V_pos_loss = 0.01634264923632145, Lv_loss = 0.004685369320213795, Circular Tuning Loss = 0.45374569296836853
# 103) Lyapunov Risk = 0.8132237195968628, MSE = 0.006206880323588848, V_0_loss = tensor([[0.0225]], grad_fn=<PowBackward0>), V_pos_loss = 0.016348717734217644, Lv_loss = 0.004543745424598455, Circular Tuning Loss = 0.45396193861961365
# 104) Lyapunov Risk = 0.8122678399085999, MSE = 0.006192862056195736, V_0_loss = tensor([[0.0224]], grad_fn=<PowBackward0>), V_pos_loss = 0.016354119405150414, Lv_loss = 0.004407739732414484, Circular Tuning Loss = 0.4541744887828827
# 105) Lyapunov Risk = 0.8113260269165039, MSE = 0.006175019778311253, V_0_loss = tensor([[0.0223]], grad_fn=<PowBackward0>), V_pos_loss = 0.016358857974410057, Lv_loss = 0.004275262355804443, Circular Tuning Loss = 0.45438337326049805
# 106) Lyapunov Risk = 0.8104056715965271, MSE = 0.006140478886663914, V_0_loss = tensor([[0.0222]], grad_fn=<PowBackward0>), V_pos_loss = 0.016362758353352547, Lv_loss = 0.0041619944386184216, Circular Tuning Loss = 0.4545878767967224
# 107) Lyapunov Risk = 0.8094922304153442, MSE = 0.006117537152022123, V_0_loss = tensor([[0.0222]], grad_fn=<PowBackward0>), V_pos_loss = 0.01636585220694542, Lv_loss = 0.004045199602842331, Circular Tuning Loss = 0.45478805899620056
# 108) Lyapunov Risk = 0.8085898160934448, MSE = 0.006094237323850393, V_0_loss = tensor([[0.0221]], grad_fn=<PowBackward0>), V_pos_loss = 0.016368092969059944, Lv_loss = 0.003927650395780802, Circular Tuning Loss = 0.4549841284751892
# 109) Lyapunov Risk = 0.8076929450035095, MSE = 0.006061673164367676, V_0_loss = tensor([[0.0220]], grad_fn=<PowBackward0>), V_pos_loss = 0.016369542106986046, Lv_loss = 0.003821183927357197, Circular Tuning Loss = 0.45517605543136597
# 110) Lyapunov Risk = 0.8068017363548279, MSE = 0.006016476545482874, V_0_loss = tensor([[0.0220]], grad_fn=<PowBackward0>), V_pos_loss = 0.01637018471956253, Lv_loss = 0.0037287226878106594, Circular Tuning Loss = 0.4553637206554413
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.0039062500000000009, 0]
# x2 : [0, 0.0039062500000000009]
# ==============================
# 111) Lyapunov Risk = 0.8035547733306885, MSE = 0.005957332439720631, V_0_loss = tensor([[0.0219]], grad_fn=<PowBackward0>), V_pos_loss = 0.016223834827542305, Lv_loss = 0.0036150156520307064, Circular Tuning Loss = 0.4516705870628357
# 112) Lyapunov Risk = 0.8026931285858154, MSE = 0.005894938018172979, V_0_loss = tensor([[0.0219]], grad_fn=<PowBackward0>), V_pos_loss = 0.016223108395934105, Lv_loss = 0.0035400253254920244, Circular Tuning Loss = 0.4518495202064514
# 113) Lyapunov Risk = 0.8018345832824707, MSE = 0.005844356492161751, V_0_loss = tensor([[0.0218]], grad_fn=<PowBackward0>), V_pos_loss = 0.016221817582845688, Lv_loss = 0.0034603991080075502, Circular Tuning Loss = 0.45202597975730896
# 114) Lyapunov Risk = 0.8009750843048096, MSE = 0.005813793279230595, V_0_loss = tensor([[0.0217]], grad_fn=<PowBackward0>), V_pos_loss = 0.016219964250922203, Lv_loss = 0.003368023782968521, Circular Tuning Loss = 0.4522000551223755
# 115) Lyapunov Risk = 0.8001143336296082, MSE = 0.005797123070806265, V_0_loss = tensor([[0.0217]], grad_fn=<PowBackward0>), V_pos_loss = 0.01621755212545395, Lv_loss = 0.0032679224386811256, Circular Tuning Loss = 0.4523714780807495
# 116) Lyapunov Risk = 0.7992562055587769, MSE = 0.005779634229838848, V_0_loss = tensor([[0.0216]], grad_fn=<PowBackward0>), V_pos_loss = 0.016214588657021523, Lv_loss = 0.0031711391638964415, Circular Tuning Loss = 0.45254045724868774
# 117) Lyapunov Risk = 0.7983971834182739, MSE = 0.005755385383963585, V_0_loss = tensor([[0.0216]], grad_fn=<PowBackward0>), V_pos_loss = 0.01621108688414097, Lv_loss = 0.0030807044822722673, Circular Tuning Loss = 0.4527067244052887
# 118) Lyapunov Risk = 0.7975441813468933, MSE = 0.0057282159104943275, V_0_loss = tensor([[0.0215]], grad_fn=<PowBackward0>), V_pos_loss = 0.016207048669457436, Lv_loss = 0.002996426075696945, Circular Tuning Loss = 0.4528702199459076
# 119) Lyapunov Risk = 0.796701192855835, MSE = 0.005702501628547907, V_0_loss = tensor([[0.0214]], grad_fn=<PowBackward0>), V_pos_loss = 0.016202552244067192, Lv_loss = 0.0029109104070812464, Circular Tuning Loss = 0.45303094387054443
# 120) Lyapunov Risk = 0.7958648800849915, MSE = 0.005685674957931042, V_0_loss = tensor([[0.0214]], grad_fn=<PowBackward0>), V_pos_loss = 0.016197528690099716, Lv_loss = 0.0028216298669576645, Circular Tuning Loss = 0.4531888961791992
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [0.50000000000000011, 0.50390625000000022]
# x2 : [0.11718750000000003, 0.12500000000000003]
# ==============================
# 121) Lyapunov Risk = 0.7951629757881165, MSE = 0.005665076430886984, V_0_loss = tensor([[0.0213]], grad_fn=<PowBackward0>), V_pos_loss = 0.01604866050183773, Lv_loss = 0.0029598912224173546, Circular Tuning Loss = 0.45160651206970215
# 122) Lyapunov Risk = 0.7943332195281982, MSE = 0.005651353392750025, V_0_loss = tensor([[0.0213]], grad_fn=<PowBackward0>), V_pos_loss = 0.016042539849877357, Lv_loss = 0.002866879105567932, Circular Tuning Loss = 0.45175695419311523
# 123) Lyapunov Risk = 0.793502688407898, MSE = 0.005633505526930094, V_0_loss = tensor([[0.0212]], grad_fn=<PowBackward0>), V_pos_loss = 0.016035838052630424, Lv_loss = 0.0027780267409980297, Circular Tuning Loss = 0.45190414786338806
# 124) Lyapunov Risk = 0.7926745414733887, MSE = 0.005608506966382265, V_0_loss = tensor([[0.0212]], grad_fn=<PowBackward0>), V_pos_loss = 0.016028540208935738, Lv_loss = 0.0026949995663017035, Circular Tuning Loss = 0.4520481526851654
# 125) Lyapunov Risk = 0.7918517589569092, MSE = 0.005589577369391918, V_0_loss = tensor([[0.0211]], grad_fn=<PowBackward0>), V_pos_loss = 0.016020676121115685, Lv_loss = 0.0026135947555303574, Circular Tuning Loss = 0.4521890878677368
# 126) Lyapunov Risk = 0.7910302877426147, MSE = 0.005588519386947155, V_0_loss = tensor([[0.0211]], grad_fn=<PowBackward0>), V_pos_loss = 0.016012271866202354, Lv_loss = 0.002526372205466032, Circular Tuning Loss = 0.45232686400413513
# 127) Lyapunov Risk = 0.7902161478996277, MSE = 0.005598139017820358, V_0_loss = tensor([[0.0210]], grad_fn=<PowBackward0>), V_pos_loss = 0.016003362834453583, Lv_loss = 0.0024350392632186413, Circular Tuning Loss = 0.4524613916873932
# 128) Lyapunov Risk = 0.789405345916748, MSE = 0.00560675747692585, V_0_loss = tensor([[0.0210]], grad_fn=<PowBackward0>), V_pos_loss = 0.01599392294883728, Lv_loss = 0.002348281443119049, Circular Tuning Loss = 0.4525926113128662
# 129) Lyapunov Risk = 0.788597583770752, MSE = 0.005609114654362202, V_0_loss = tensor([[0.0209]], grad_fn=<PowBackward0>), V_pos_loss = 0.015983946621418, Lv_loss = 0.002269916934892535, Circular Tuning Loss = 0.45272040367126465
# 130) Lyapunov Risk = 0.7877897620201111, MSE = 0.005610192660242319, V_0_loss = tensor([[0.0209]], grad_fn=<PowBackward0>), V_pos_loss = 0.015973376110196114, Lv_loss = 0.0021970579400658607, Circular Tuning Loss = 0.4528450071811676
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.0039062500000000009, 0]
# x2 : [0, 0.0039062500000000009]
# ==============================
# 131) Lyapunov Risk = 0.7847827076911926, MSE = 0.005620500072836876, V_0_loss = tensor([[0.0208]], grad_fn=<PowBackward0>), V_pos_loss = 0.01582222990691662, Lv_loss = 0.0021036735270172358, Circular Tuning Loss = 0.44917061924934387
# 132) Lyapunov Risk = 0.7839873433113098, MSE = 0.005644548684358597, V_0_loss = tensor([[0.0208]], grad_fn=<PowBackward0>), V_pos_loss = 0.015810996294021606, Lv_loss = 0.0020268030930310488, Circular Tuning Loss = 0.44928932189941406
# 133) Lyapunov Risk = 0.7831928133964539, MSE = 0.0056656780652701855, V_0_loss = tensor([[0.0207]], grad_fn=<PowBackward0>), V_pos_loss = 0.015799591317772865, Lv_loss = 0.001955464482307434, Circular Tuning Loss = 0.44940656423568726
# 134) Lyapunov Risk = 0.7823981642723083, MSE = 0.005668895319104195, V_0_loss = tensor([[0.0207]], grad_fn=<PowBackward0>), V_pos_loss = 0.015788139775395393, Lv_loss = 0.0018977909348905087, Circular Tuning Loss = 0.4495224356651306
# 135) Lyapunov Risk = 0.781606137752533, MSE = 0.005658715032041073, V_0_loss = tensor([[0.0207]], grad_fn=<PowBackward0>), V_pos_loss = 0.01577647775411606, Lv_loss = 0.001852263929322362, Circular Tuning Loss = 0.44963693618774414
# 136) Lyapunov Risk = 0.7808207869529724, MSE = 0.0056396727450191975, V_0_loss = tensor([[0.0206]], grad_fn=<PowBackward0>), V_pos_loss = 0.015764586627483368, Lv_loss = 0.0018159891478717327, Circular Tuning Loss = 0.4497498571872711
# 137) Lyapunov Risk = 0.7800416350364685, MSE = 0.005614009685814381, V_0_loss = tensor([[0.0206]], grad_fn=<PowBackward0>), V_pos_loss = 0.0157524012029171, Lv_loss = 0.0017863850807771087, Circular Tuning Loss = 0.449861079454422
# 138) Lyapunov Risk = 0.7792628407478333, MSE = 0.005585381295531988, V_0_loss = tensor([[0.0205]], grad_fn=<PowBackward0>), V_pos_loss = 0.01573992893099785, Lv_loss = 0.0017605668399482965, Circular Tuning Loss = 0.4499705135822296
# 139) Lyapunov Risk = 0.7784913182258606, MSE = 0.005548449698835611, V_0_loss = tensor([[0.0205]], grad_fn=<PowBackward0>), V_pos_loss = 0.01572716049849987, Lv_loss = 0.0017411154694855213, Circular Tuning Loss = 0.4500780999660492
# 140) Lyapunov Risk = 0.7777224779129028, MSE = 0.005503520369529724, V_0_loss = tensor([[0.0205]], grad_fn=<PowBackward0>), V_pos_loss = 0.015714101493358612, Lv_loss = 0.0017287222435697913, Circular Tuning Loss = 0.4501838684082031
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [0.15234375000000006, 0.15625000000000006]
# x2 : [-0.0039062500000000009, 0]
# ==============================
# 141) Lyapunov Risk = 0.7749673128128052, MSE = 0.005457635503262281, V_0_loss = tensor([[0.0204]], grad_fn=<PowBackward0>), V_pos_loss = 0.015564203262329102, Lv_loss = 0.0018371179467067122, Circular Tuning Loss = 0.4464033842086792
# 142) Lyapunov Risk = 0.7742132544517517, MSE = 0.00543147511780262, V_0_loss = tensor([[0.0204]], grad_fn=<PowBackward0>), V_pos_loss = 0.015550813637673855, Lv_loss = 0.0018187889363616705, Circular Tuning Loss = 0.4465055465698242
# 143) Lyapunov Risk = 0.7734622955322266, MSE = 0.005418339278548956, V_0_loss = tensor([[0.0203]], grad_fn=<PowBackward0>), V_pos_loss = 0.015537227503955364, Lv_loss = 0.0017944513820111752, Circular Tuning Loss = 0.44660666584968567
# 144) Lyapunov Risk = 0.7727164030075073, MSE = 0.00540596479550004, V_0_loss = tensor([[0.0203]], grad_fn=<PowBackward0>), V_pos_loss = 0.015523383393883705, Lv_loss = 0.0017685311613604426, Circular Tuning Loss = 0.44670653343200684
# 145) Lyapunov Risk = 0.7719736695289612, MSE = 0.0053906370885670185, V_0_loss = tensor([[0.0203]], grad_fn=<PowBackward0>), V_pos_loss = 0.015509257093071938, Lv_loss = 0.0017441969830542803, Circular Tuning Loss = 0.44680505990982056
# 146) Lyapunov Risk = 0.7712315917015076, MSE = 0.0053705377504229546, V_0_loss = tensor([[0.0202]], grad_fn=<PowBackward0>), V_pos_loss = 0.015494829043745995, Lv_loss = 0.0017221698071807623, Circular Tuning Loss = 0.44690221548080444
# 147) Lyapunov Risk = 0.7704892754554749, MSE = 0.005353765096515417, V_0_loss = tensor([[0.0202]], grad_fn=<PowBackward0>), V_pos_loss = 0.015480101108551025, Lv_loss = 0.001700058812275529, Circular Tuning Loss = 0.4469979703426361
# 148) Lyapunov Risk = 0.7697477340698242, MSE = 0.005339357070624828, V_0_loss = tensor([[0.0202]], grad_fn=<PowBackward0>), V_pos_loss = 0.01546507328748703, Lv_loss = 0.0016784199979156256, Circular Tuning Loss = 0.44709229469299316
# 149) Lyapunov Risk = 0.7690109610557556, MSE = 0.005317032802850008, V_0_loss = tensor([[0.0201]], grad_fn=<PowBackward0>), V_pos_loss = 0.015449708327651024, Lv_loss = 0.0016609150916337967, Circular Tuning Loss = 0.44718506932258606
# 150) Lyapunov Risk = 0.7682777047157288, MSE = 0.005288298241794109, V_0_loss = tensor([[0.0201]], grad_fn=<PowBackward0>), V_pos_loss = 0.01543407142162323, Lv_loss = 0.0016462341882288456, Circular Tuning Loss = 0.44727617502212524
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.0039062500000000009, 0]
# x2 : [0, 0.0078125000000000017]
# ==============================
# 151) Lyapunov Risk = 0.7655174136161804, MSE = 0.0052557759918272495, V_0_loss = tensor([[0.0201]], grad_fn=<PowBackward0>), V_pos_loss = 0.0152852488681674, Lv_loss = 0.0016181679675355554, Circular Tuning Loss = 0.4436742961406708
# 152) Lyapunov Risk = 0.764802098274231, MSE = 0.005243280902504921, V_0_loss = tensor([[0.0200]], grad_fn=<PowBackward0>), V_pos_loss = 0.015269485302269459, Lv_loss = 0.0015954056289047003, Circular Tuning Loss = 0.4437626898288727
# 153) Lyapunov Risk = 0.7640936970710754, MSE = 0.005237727425992489, V_0_loss = tensor([[0.0200]], grad_fn=<PowBackward0>), V_pos_loss = 0.015253657475113869, Lv_loss = 0.0015697130002081394, Circular Tuning Loss = 0.4438508152961731
# 154) Lyapunov Risk = 0.7633867859840393, MSE = 0.005233805160969496, V_0_loss = tensor([[0.0200]], grad_fn=<PowBackward0>), V_pos_loss = 0.015237743966281414, Lv_loss = 0.001542906858958304, Circular Tuning Loss = 0.44393858313560486
# 155) Lyapunov Risk = 0.7626822590827942, MSE = 0.005229619797319174, V_0_loss = tensor([[0.0199]], grad_fn=<PowBackward0>), V_pos_loss = 0.015221712179481983, Lv_loss = 0.0015153501881286502, Circular Tuning Loss = 0.44402554631233215
# 156) Lyapunov Risk = 0.7619788646697998, MSE = 0.005222874227911234, V_0_loss = tensor([[0.0199]], grad_fn=<PowBackward0>), V_pos_loss = 0.015205512754619122, Lv_loss = 0.0014893434708938003, Circular Tuning Loss = 0.44411173462867737
# 157) Lyapunov Risk = 0.761276364326477, MSE = 0.005225674714893103, V_0_loss = tensor([[0.0199]], grad_fn=<PowBackward0>), V_pos_loss = 0.015189151279628277, Lv_loss = 0.0014584856107831001, Circular Tuning Loss = 0.4441969692707062
# 158) Lyapunov Risk = 0.760576605796814, MSE = 0.005229227244853973, V_0_loss = tensor([[0.0198]], grad_fn=<PowBackward0>), V_pos_loss = 0.015172588638961315, Lv_loss = 0.0014267697697505355, Circular Tuning Loss = 0.4442812204360962
# 159) Lyapunov Risk = 0.759881854057312, MSE = 0.005227549001574516, V_0_loss = tensor([[0.0198]], grad_fn=<PowBackward0>), V_pos_loss = 0.0151559142395854, Lv_loss = 0.001397519838064909, Circular Tuning Loss = 0.4443642497062683
# 160) Lyapunov Risk = 0.759192168712616, MSE = 0.005213623866438866, V_0_loss = tensor([[0.0198]], grad_fn=<PowBackward0>), V_pos_loss = 0.015138969756662846, Lv_loss = 0.0013747888151556253, Circular Tuning Loss = 0.4444459080696106
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [0.18359375000000006, 0.18554687500000006]
# x2 : [-0.027343750000000007, -0.023437500000000007]
# ==============================
# 161) Lyapunov Risk = 0.756730318069458, MSE = 0.005192896351218224, V_0_loss = tensor([[0.0197]], grad_fn=<PowBackward0>), V_pos_loss = 0.014992722310125828, Lv_loss = 0.0014836874324828386, Circular Tuning Loss = 0.4408232867717743
# 162) Lyapunov Risk = 0.7560538053512573, MSE = 0.00519069517031312, V_0_loss = tensor([[0.0197]], grad_fn=<PowBackward0>), V_pos_loss = 0.01497596874833107, Lv_loss = 0.0014562300639227033, Circular Tuning Loss = 0.4409028887748718
# 163) Lyapunov Risk = 0.7553790807723999, MSE = 0.005201902240514755, V_0_loss = tensor([[0.0197]], grad_fn=<PowBackward0>), V_pos_loss = 0.014959177002310753, Lv_loss = 0.0014228543732315302, Circular Tuning Loss = 0.440982460975647
# 164) Lyapunov Risk = 0.7547110319137573, MSE = 0.005200556013733149, V_0_loss = tensor([[0.0196]], grad_fn=<PowBackward0>), V_pos_loss = 0.01494226511567831, Lv_loss = 0.001396157662384212, Circular Tuning Loss = 0.44106143712997437
# 165) Lyapunov Risk = 0.7540509700775146, MSE = 0.005182604771107435, V_0_loss = tensor([[0.0196]], grad_fn=<PowBackward0>), V_pos_loss = 0.014925195835530758, Lv_loss = 0.00137863599229604, Circular Tuning Loss = 0.4411398768424988
# 166) Lyapunov Risk = 0.7533965110778809, MSE = 0.005163697991520166, V_0_loss = tensor([[0.0196]], grad_fn=<PowBackward0>), V_pos_loss = 0.014907934702932835, Lv_loss = 0.0013635253999382257, Circular Tuning Loss = 0.4412175118923187
# 167) Lyapunov Risk = 0.752745509147644, MSE = 0.0051619927398860455, V_0_loss = tensor([[0.0196]], grad_fn=<PowBackward0>), V_pos_loss = 0.014890579506754875, Lv_loss = 0.001343177747912705, Circular Tuning Loss = 0.44129452109336853
# 168) Lyapunov Risk = 0.7521002888679504, MSE = 0.0051621366292238235, V_0_loss = tensor([[0.0195]], grad_fn=<PowBackward0>), V_pos_loss = 0.014873011969029903, Lv_loss = 0.00132327142637223, Circular Tuning Loss = 0.4413706064224243
# 169) Lyapunov Risk = 0.7514607906341553, MSE = 0.0051458063535392284, V_0_loss = tensor([[0.0195]], grad_fn=<PowBackward0>), V_pos_loss = 0.014855213463306427, Lv_loss = 0.001311651081778109, Circular Tuning Loss = 0.44144585728645325
# 170) Lyapunov Risk = 0.750827431678772, MSE = 0.0051116943359375, V_0_loss = tensor([[0.0195]], grad_fn=<PowBackward0>), V_pos_loss = 0.014837163500487804, Lv_loss = 0.0013089298736304045, Circular Tuning Loss = 0.4415200650691986
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.0039062500000000009, 0]
# x2 : [0, 0.0078125000000000017]
# ==============================
# 171) Lyapunov Risk = 0.7483276128768921, MSE = 0.005073261447250843, V_0_loss = tensor([[0.0194]], grad_fn=<PowBackward0>), V_pos_loss = 0.014693250879645348, Lv_loss = 0.0012978831073269248, Circular Tuning Loss = 0.43800896406173706
# 172) Lyapunov Risk = 0.7477039098739624, MSE = 0.005065214354544878, V_0_loss = tensor([[0.0194]], grad_fn=<PowBackward0>), V_pos_loss = 0.014675186015665531, Lv_loss = 0.0012851270148530602, Circular Tuning Loss = 0.438082218170166
# 173) Lyapunov Risk = 0.7470868229866028, MSE = 0.005069864448159933, V_0_loss = tensor([[0.0194]], grad_fn=<PowBackward0>), V_pos_loss = 0.014657200314104557, Lv_loss = 0.001268439693376422, Circular Tuning Loss = 0.43815597891807556
# 174) Lyapunov Risk = 0.7464722990989685, MSE = 0.005059222225099802, V_0_loss = tensor([[0.0194]], grad_fn=<PowBackward0>), V_pos_loss = 0.014639267697930336, Lv_loss = 0.0012591207632794976, Circular Tuning Loss = 0.43822988867759705
# 175) Lyapunov Risk = 0.7458635568618774, MSE = 0.005030873231589794, V_0_loss = tensor([[0.0193]], grad_fn=<PowBackward0>), V_pos_loss = 0.014621411450207233, Lv_loss = 0.0012584156356751919, Circular Tuning Loss = 0.43830400705337524
# 176) Lyapunov Risk = 0.7452622056007385, MSE = 0.00500284181907773, V_0_loss = tensor([[0.0193]], grad_fn=<PowBackward0>), V_pos_loss = 0.014603557996451855, Lv_loss = 0.001258117496035993, Circular Tuning Loss = 0.43837806582450867
# 177) Lyapunov Risk = 0.7446656823158264, MSE = 0.0049955579452216625, V_0_loss = tensor([[0.0193]], grad_fn=<PowBackward0>), V_pos_loss = 0.014585595577955246, Lv_loss = 0.0012487673666328192, Circular Tuning Loss = 0.4384520351886749
# 178) Lyapunov Risk = 0.7440738081932068, MSE = 0.004987286403775215, V_0_loss = tensor([[0.0192]], grad_fn=<PowBackward0>), V_pos_loss = 0.014567476697266102, Lv_loss = 0.001240908750332892, Circular Tuning Loss = 0.43852585554122925
# 179) Lyapunov Risk = 0.7434867024421692, MSE = 0.004958683624863625, V_0_loss = tensor([[0.0192]], grad_fn=<PowBackward0>), V_pos_loss = 0.014549163170158863, Lv_loss = 0.001242950209416449, Circular Tuning Loss = 0.4385991394519806
# 180) Lyapunov Risk = 0.7429081201553345, MSE = 0.0049029067158699036, V_0_loss = tensor([[0.0192]], grad_fn=<PowBackward0>), V_pos_loss = 0.014530704356729984, Lv_loss = 0.0012575824512168765, Circular Tuning Loss = 0.4386718273162842
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [0.18750000000000006, 0.19140625000000006]
# x2 : [-0.0019531250000000004, 0]
# ==============================
# 181) Lyapunov Risk = 0.7407084107398987, MSE = 0.004851086996495724, V_0_loss = tensor([[0.0192]], grad_fn=<PowBackward0>), V_pos_loss = 0.014390124939382076, Lv_loss = 0.0014173908857628703, Circular Tuning Loss = 0.4351557493209839
# 182) Lyapunov Risk = 0.740147590637207, MSE = 0.004835317377001047, V_0_loss = tensor([[0.0191]], grad_fn=<PowBackward0>), V_pos_loss = 0.014371509663760662, Lv_loss = 0.0014134790981188416, Circular Tuning Loss = 0.4352271854877472
# 183) Lyapunov Risk = 0.7395920157432556, MSE = 0.004830008372664452, V_0_loss = tensor([[0.0191]], grad_fn=<PowBackward0>), V_pos_loss = 0.014352809637784958, Lv_loss = 0.001403463538736105, Circular Tuning Loss = 0.43529853224754333
# 184) Lyapunov Risk = 0.7390390634536743, MSE = 0.004808275029063225, V_0_loss = tensor([[0.0191]], grad_fn=<PowBackward0>), V_pos_loss = 0.014333878643810749, Lv_loss = 0.001400311361066997, Circular Tuning Loss = 0.4353695511817932
# 185) Lyapunov Risk = 0.7384883165359497, MSE = 0.0047806245274841785, V_0_loss = tensor([[0.0190]], grad_fn=<PowBackward0>), V_pos_loss = 0.014314696192741394, Lv_loss = 0.0013998191570863128, Circular Tuning Loss = 0.4354400932788849
# 186) Lyapunov Risk = 0.7379400134086609, MSE = 0.004773204680532217, V_0_loss = tensor([[0.0190]], grad_fn=<PowBackward0>), V_pos_loss = 0.014295253902673721, Lv_loss = 0.0013888071989640594, Circular Tuning Loss = 0.4355100393295288
# 187) Lyapunov Risk = 0.7373940348625183, MSE = 0.004784042946994305, V_0_loss = tensor([[0.0190]], grad_fn=<PowBackward0>), V_pos_loss = 0.014275526627898216, Lv_loss = 0.0013682314893230796, Circular Tuning Loss = 0.43557924032211304
# 188) Lyapunov Risk = 0.7368558645248413, MSE = 0.004792790859937668, V_0_loss = tensor([[0.0190]], grad_fn=<PowBackward0>), V_pos_loss = 0.01425551064312458, Lv_loss = 0.0013481879141181707, Circular Tuning Loss = 0.43564754724502563
# 189) Lyapunov Risk = 0.7363212704658508, MSE = 0.0047772834077477455, V_0_loss = tensor([[0.0189]], grad_fn=<PowBackward0>), V_pos_loss = 0.014235178008675575, Lv_loss = 0.001339903217740357, Circular Tuning Loss = 0.4357149600982666
# ...
# 1019) Lyapunov Risk = 0.716331422328949, MSE = 0.0005812324234284461, V_0_loss = tensor([[0.0081]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0015474564861506224, Circular Tuning Loss = 0.5109251737594604
# 1020) Lyapunov Risk = 0.7162110805511475, MSE = 0.0005104583688080311, V_0_loss = tensor([[0.0081]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0015971650136634707, Circular Tuning Loss = 0.5108625888824463
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [1.0717067764657746, 1.0750170001627524]
# x2 : [-1.6864008906762127, -1.684179684707549]
# ==============================
# 1021) Lyapunov Risk = 0.7332596182823181, MSE = 0.0005994286620989442, V_0_loss = tensor([[0.0081]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.001625595847144723, Circular Tuning Loss = 0.5272917747497559
# 1022) Lyapunov Risk = 0.7331361770629883, MSE = 0.0004990044981241226, V_0_loss = tensor([[0.0081]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016922308132052422, Circular Tuning Loss = 0.5272266268730164
# 1023) Lyapunov Risk = 0.7330109477043152, MSE = 0.0006072797696106136, V_0_loss = tensor([[0.0081]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.001618372043594718, Circular Tuning Loss = 0.5271578431129456
# 1024) Lyapunov Risk = 0.7328838109970093, MSE = 0.0004947776324115694, V_0_loss = tensor([[0.0081]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.001691372599452734, Circular Tuning Loss = 0.527086079120636
# 1025) Lyapunov Risk = 0.7327550053596497, MSE = 0.0006072845426388085, V_0_loss = tensor([[0.0081]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016132310265675187, Circular Tuning Loss = 0.5270116925239563
# 1026) Lyapunov Risk = 0.732624888420105, MSE = 0.0004994951304979622, V_0_loss = tensor([[0.0081]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016819406300783157, Circular Tuning Loss = 0.5269353985786438
# 1027) Lyapunov Risk = 0.7324939370155334, MSE = 0.0006011103396303952, V_0_loss = tensor([[0.0081]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016102161025628448, Circular Tuning Loss = 0.526857316493988
# 1028) Lyapunov Risk = 0.7323626279830933, MSE = 0.000506268348544836, V_0_loss = tensor([[0.0081]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016696511302143335, Circular Tuning Loss = 0.5267781615257263
# 1029) Lyapunov Risk = 0.7322312593460083, MSE = 0.0005896746879443526, V_0_loss = tensor([[0.0081]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016098771011456847, Circular Tuning Loss = 0.5266979336738586
# 1030) Lyapunov Risk = 0.7321001887321472, MSE = 0.000513859442435205, V_0_loss = tensor([[0.0082]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016565773403272033, Circular Tuning Loss = 0.526617169380188
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.0078125000000000017, 0]
# x2 : [0, 0.0078125000000000017]
# ==============================
# 1031) Lyapunov Risk = 0.7300463914871216, MSE = 0.0005804921966046095, V_0_loss = tensor([[0.0082]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016002204502001405, Circular Tuning Loss = 0.5239900946617126
# 1032) Lyapunov Risk = 0.729915976524353, MSE = 0.000527496449649334, V_0_loss = tensor([[0.0082]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016314433887600899, Circular Tuning Loss = 0.5239105820655823
# 1033) Lyapunov Risk = 0.7297860980033875, MSE = 0.0005707570817321539, V_0_loss = tensor([[0.0082]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0015990782994776964, Circular Tuning Loss = 0.5238323211669922
# 1034) Lyapunov Risk = 0.7296565771102905, MSE = 0.0005393062601797283, V_0_loss = tensor([[0.0082]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016164310509338975, Circular Tuning Loss = 0.5237552523612976
# 1035) Lyapunov Risk = 0.729527473449707, MSE = 0.0005610171356238425, V_0_loss = tensor([[0.0082]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0015987805090844631, Circular Tuning Loss = 0.5236793756484985
# 1036) Lyapunov Risk = 0.7293984293937683, MSE = 0.0005481084808707237, V_0_loss = tensor([[0.0082]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016043384093791246, Circular Tuning Loss = 0.5236049890518188
# 1037) Lyapunov Risk = 0.7292697429656982, MSE = 0.0005538436234928668, V_0_loss = tensor([[0.0082]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0015987154329195619, Circular Tuning Loss = 0.5235320329666138
# 1038) Lyapunov Risk = 0.7291410565376282, MSE = 0.0005575823597609997, V_0_loss = tensor([[0.0082]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.001595919020473957, Circular Tuning Loss = 0.5234606266021729
# 1039) Lyapunov Risk = 0.7290124297142029, MSE = 0.0005500972620211542, V_0_loss = tensor([[0.0082]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016006267396733165, Circular Tuning Loss = 0.5233908295631409
# 1040) Lyapunov Risk = 0.7288837432861328, MSE = 0.0005655441782437265, V_0_loss = tensor([[0.0082]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.001590113271959126, Circular Tuning Loss = 0.523322582244873
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [1.0040678955669891, 1.0081357911339777]
# x2 : [-1.6914558667664819, -1.6880729550329487]
# ==============================
# 1041) Lyapunov Risk = 0.7451134920120239, MSE = 0.0005450349417515099, V_0_loss = tensor([[0.0082]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016779635334387422, Circular Tuning Loss = 0.5389606952667236
# 1042) Lyapunov Risk = 0.7449809312820435, MSE = 0.0005654699052684009, V_0_loss = tensor([[0.0082]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016605380224063993, Circular Tuning Loss = 0.538890540599823
# 1043) Lyapunov Risk = 0.7448478937149048, MSE = 0.0005410650046542287, V_0_loss = tensor([[0.0083]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.00167244637850672, Circular Tuning Loss = 0.5388169288635254
# 1044) Lyapunov Risk = 0.7447145581245422, MSE = 0.0005681910552084446, V_0_loss = tensor([[0.0083]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016498612239956856, Circular Tuning Loss = 0.5387405157089233
# 1045) Lyapunov Risk = 0.7445810437202454, MSE = 0.0005387500859797001, V_0_loss = tensor([[0.0083]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016644879942759871, Circular Tuning Loss = 0.5386619567871094
# 1046) Lyapunov Risk = 0.7444474101066589, MSE = 0.0005756252794526517, V_0_loss = tensor([[0.0083]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016349818324670196, Circular Tuning Loss = 0.5385811924934387
# 1047) Lyapunov Risk = 0.7443135380744934, MSE = 0.0005345184472389519, V_0_loss = tensor([[0.0083]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016569840954616666, Circular Tuning Loss = 0.538499116897583
# 1048) Lyapunov Risk = 0.7441799640655518, MSE = 0.0005830609588883817, V_0_loss = tensor([[0.0083]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016195792704820633, Circular Tuning Loss = 0.5384159088134766
# 1049) Lyapunov Risk = 0.7440468668937683, MSE = 0.0005250069661997259, V_0_loss = tensor([[0.0083]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016530529828742146, Circular Tuning Loss = 0.538331925868988
# 1050) Lyapunov Risk = 0.7439148426055908, MSE = 0.0005969888879917562, V_0_loss = tensor([[0.0083]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016006894875317812, Circular Tuning Loss = 0.5382475256919861
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.0078125000000000017, 0]
# x2 : [0, 0.0078125000000000017]
# ==============================
# 1051) Lyapunov Risk = 0.7418262958526611, MSE = 0.0005144440801814198, V_0_loss = tensor([[0.0083]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016436204314231873, Circular Tuning Loss = 0.5355862975120544
# 1052) Lyapunov Risk = 0.7417014241218567, MSE = 0.0006298678345046937, V_0_loss = tensor([[0.0083]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0015680952928960323, Circular Tuning Loss = 0.5355036854743958
# 1053) Lyapunov Risk = 0.7415825128555298, MSE = 0.0004972070455551147, V_0_loss = tensor([[0.0083]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016571520827710629, Circular Tuning Loss = 0.5354227423667908
# 1054) Lyapunov Risk = 0.7414736747741699, MSE = 0.0006839230773039162, V_0_loss = tensor([[0.0084]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0015391050837934017, Circular Tuning Loss = 0.5353432893753052
# 1055) Lyapunov Risk = 0.7413812279701233, MSE = 0.0004726873303297907, V_0_loss = tensor([[0.0084]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.001685788738541305, Circular Tuning Loss = 0.5352655053138733
# 1056) Lyapunov Risk = 0.7413136959075928, MSE = 0.0007811679388396442, V_0_loss = tensor([[0.0084]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0014970211777836084, Circular Tuning Loss = 0.5351893305778503
# 1057) Lyapunov Risk = 0.741280734539032, MSE = 0.0004572020552586764, V_0_loss = tensor([[0.0084]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0017311013070866466, Circular Tuning Loss = 0.5351145267486572
# 1058) Lyapunov Risk = 0.7412852644920349, MSE = 0.0009485460468567908, V_0_loss = tensor([[0.0084]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0014381089713424444, Circular Tuning Loss = 0.5350407958030701
# 1059) Lyapunov Risk = 0.7413120269775391, MSE = 0.0004734962130896747, V_0_loss = tensor([[0.0084]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0017869062721729279, Circular Tuning Loss = 0.5349687337875366
# 1060) Lyapunov Risk = 0.7413079738616943, MSE = 0.0011212724493816495, V_0_loss = tensor([[0.0084]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0013871779665350914, Circular Tuning Loss = 0.5348974466323853
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [0.93750000000000022, 0.94140625000000022]
# x2 : [-1.7436183294282941, -1.7390096446863887]
# ==============================
# 1061) Lyapunov Risk = 0.7575574517250061, MSE = 0.0004881572676822543, V_0_loss = tensor([[0.0084]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.00187842664308846, Circular Tuning Loss = 0.550573468208313
# 1062) Lyapunov Risk = 0.7572373747825623, MSE = 0.0010169167071580887, V_0_loss = tensor([[0.0084]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0014805140672251582, Circular Tuning Loss = 0.5505003333091736
# 1063) Lyapunov Risk = 0.7568061947822571, MSE = 0.00046059457235969603, V_0_loss = tensor([[0.0084]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.001776865334250033, Circular Tuning Loss = 0.5504245162010193
# 1064) Lyapunov Risk = 0.7564495205879211, MSE = 0.0006460532895289361, V_0_loss = tensor([[0.0084]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.001602286472916603, Circular Tuning Loss = 0.5503450632095337
# 1065) Lyapunov Risk = 0.7562887072563171, MSE = 0.0006198697374202311, V_0_loss = tensor([[0.0084]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016105904942378402, Circular Tuning Loss = 0.5502629280090332
# 1066) Lyapunov Risk = 0.7562838792800903, MSE = 0.00047197379171848297, V_0_loss = tensor([[0.0084]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0017353387083858252, Circular Tuning Loss = 0.5501787066459656
# 1067) Lyapunov Risk = 0.7562848329544067, MSE = 0.0008679517777636647, V_0_loss = tensor([[0.0085]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.001505348365753889, Circular Tuning Loss = 0.5500922799110413
# 1068) Lyapunov Risk = 0.7561582326889038, MSE = 0.0004631042538676411, V_0_loss = tensor([[0.0085]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0017716834554448724, Circular Tuning Loss = 0.5500057935714722
# 1069) Lyapunov Risk = 0.7558916211128235, MSE = 0.0007914716261439025, V_0_loss = tensor([[0.0085]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0015277371276170015, Circular Tuning Loss = 0.5499182343482971
# 1070) Lyapunov Risk = 0.7556017637252808, MSE = 0.0005018158117309213, V_0_loss = tensor([[0.0085]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016832826659083366, Circular Tuning Loss = 0.5498314499855042
# ===========Verifying==========
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.0078125000000000017, 0]
# x2 : [0, 0.0078125000000000017]
# ==============================
# 1071) Lyapunov Risk = 0.7534189820289612, MSE = 0.0005528104957193136, V_0_loss = tensor([[0.0085]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.001630567479878664, Circular Tuning Loss = 0.5471382737159729
# 1072) Lyapunov Risk = 0.7533449530601501, MSE = 0.0006917563150636852, V_0_loss = tensor([[0.0085]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0015543174231424928, Circular Tuning Loss = 0.5470535159111023
# 1073) Lyapunov Risk = 0.7532892227172852, MSE = 0.00047575999633409083, V_0_loss = tensor([[0.0085]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0017121246783062816, Circular Tuning Loss = 0.5469710826873779
# 1074) Lyapunov Risk = 0.7531558871269226, MSE = 0.0007778667495585978, V_0_loss = tensor([[0.0085]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0015173624269664288, Circular Tuning Loss = 0.5468902587890625
# 1075) Lyapunov Risk = 0.7529390454292297, MSE = 0.0004858530010096729, V_0_loss = tensor([[0.0085]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016894275322556496, Circular Tuning Loss = 0.5468121767044067
# 1076) Lyapunov Risk = 0.7527152299880981, MSE = 0.0006241669761948287, V_0_loss = tensor([[0.0085]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.001581162097863853, Circular Tuning Loss = 0.5467360019683838
# 1077) Lyapunov Risk = 0.7525556087493896, MSE = 0.0005928233731538057, V_0_loss = tensor([[0.0085]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0015968859661370516, Circular Tuning Loss = 0.5466623902320862
# 1078) Lyapunov Risk = 0.7524562478065491, MSE = 0.0005060387775301933, V_0_loss = tensor([[0.0085]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016616486245766282, Circular Tuning Loss = 0.54659104347229
# 1079) Lyapunov Risk = 0.7523567080497742, MSE = 0.0007178960368037224, V_0_loss = tensor([[0.0086]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0015326541615650058, Circular Tuning Loss = 0.5465223789215088
# 1080) Lyapunov Risk = 0.7522071599960327, MSE = 0.0004940745420753956, V_0_loss = tensor([[0.0086]], grad_fn=<PowBackward0>), V_pos_loss = 0.0, Lv_loss = 0.0016747638583183289, Circular Tuning Loss = 0.5464566946029663
# ===========Verifying==========
# Satisfy conditions
# tanh((0.27410349249839783 + 0.039584971964359283 * tanh((-0.78580248355865479 - 0.54179686307907104 * x1 - 0.44331333041191101 * x2)) + 0.032003968954086304 * tanh((-0.30596265196800232 + 0.28868582844734192 * x1 - 0.44616582989692688 * x2)) + 0.19545562565326691 * tanh((-0.20542848110198975 - 0.59209489822387695 * x1 - 0.11210347712039948 * x2)) - 0.34900319576263428 * tanh((-0.15178127586841583 + 0.41529247164726257 * x1 - 0.2868499755859375 * x2)) - 0.50081431865692139 * tanh((-0.10578529536724091 - 0.077790796756744385 * x1 - 0.12398010492324829 * x2)) + 0.21453848481178284 * tanh((0.023654472082853317 - 0.0034681777469813824 * x1 + 0.32614058256149292 * x2)) + 0.1472405344247818 * tanh((0.24145704507827759 + 0.22005608677864075 * x1 + 0.097926110029220581 * x2)) - 0.48210272192955017 * tanh((0.51193320751190186 - 0.38844358921051025 * x1 + 0.28009822964668274 * x2)) + 0.068316079676151276 * tanh((0.51267856359481812 + 0.76190376281738281 * x1 - 0.23304438591003418 * x2)) - 0.10667768865823746 * tanh((0.58962452411651611 + 0.61752521991729736 * x1 + 0.30307349562644958 * x2))))  is a Lyapunov function.
# ==============================
#
#
# Total time:  78.21046620500056
# Verified time:  6.844922722000774

# %%
# Checking Result with Bounded Beta
beta = -0.02
start_ = timeit.default_timer() 
result = CheckLyapunov(vars_, f_learn, V_learn, ball_lb, ball_ub, config, beta)
stop_ = timeit.default_timer() 

if (result): 
    print("Not a Lyapunov function. Found counterexample: ")
    print(result)
else:  
    print("Satisfy conditions with beta = ",beta)
    print(V_learn, " is a Lyapunov function.")
t += (stop_ - start_)
# Out:
# Not a Lyapunov function. Found counterexample:
# x1 : [-0.0078125000000000017, 0]
# x2 : [0, 0.0078125000000000017]

# %%
beta = 0
f = [-2*x1 + x2,
        -x1 - 2*x2]
start_ = timeit.default_timer() 
result = CheckLyapunov(vars_, f, V_learn, ball_lb, ball_ub, config, beta)
stop_ = timeit.default_timer() 
if (result): 
    print("Not a Lyapunov function. Found counterexample: ")
    print(result)
else:  
    print("Satisfy conditions with beta= ", beta)
    print(V_learn, " is a Lyapunov function for actual dynamics.")
t += (stop_ - start_)
# Out:
# Not a Lyapunov function. Found counterexample:
# x1 : [-1.8125000000000004, -1.8085937500000004]
# x2 : [0, 0.0067658234670659274]

# %%
# Plotting the Lyapunov Function
fig, ax = plt.subplots()
# Define grid for plotting
len_sample = [256, 256]
x = np.linspace(-1, 1, len_sample[0])
y = np.linspace(-1, 1, len_sample[1])
X, Y = np.meshgrid(x, y)

# Convert X and Y to torch tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
Y_tensor = torch.tensor(Y, dtype=torch.float32)

# Concatenate X and Y to create input data tensor
input_data = torch.stack((X_tensor, Y_tensor), dim=-1).reshape(-1, 2)
unflatten = torch.nn.Unflatten(0, len_sample)

# Lyapunov Function
with torch.no_grad():
    V = model_v(input_data)
    cont_out = unflatten(V)
    cont_out = cont_out.detach().numpy()
# Plot the vector field
cp = ax.contourf(X, Y, cont_out[:,:,0])
fig.colorbar(cp)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Lyapunov Function')
plt.show()

# %%
# Plot the Lyapunov function in 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, cont_out[:,:,0], cmap='viridis')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('Lyapunov Function Value')
ax.set_title('Lyapunov Function')
plt.show()

# %% [markdown]
# ## Ideal Plots for the Lyapunov Function and the Vector Field

# %%
fig, ax = plt.subplots()
# Define grid for plotting
len_sample = [256, 256]
x = np.linspace(-1, 1, len_sample[0])
y = np.linspace(-1, 1, len_sample[1])
X, Y = np.meshgrid(x, y)

# Convert X and Y to torch tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
Y_tensor = torch.tensor(Y, dtype=torch.float32)

# Concatenate X and Y to create input data tensor
input_data = torch.stack((X_tensor, Y_tensor), dim=-1).reshape(-1, 2)
unflatten = torch.nn.Unflatten(0, len_sample)

# Vector Field
with torch.no_grad():
    F = torch.empty(len(input_data),2, dtype=torch.float32)
    for i in range(len(input_data)):
        x = input_data[i,:].unsqueeze(1)
        F[i,:] = torch.reshape(torch.matmul(A,x)[:],(1,-1))
    vect_out = unflatten(F)
    vect_out = vect_out.detach().numpy()
    U = vect_out[:,:, 0]
    V = vect_out[:,:,1]
ax.streamplot(X, Y, U, V, density=1.4, linewidth=None, color='b')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Vector Field for Neural Network Dynamical System')

# Lyapunov Function
V = torch.empty(len(input_data),1, dtype=torch.float32)
for i in range(len(input_data)):
    x = input_data[i,:]
    x_T = input_data[i,:].unsqueeze(1) 
    V[i] = torch.matmul(torch.matmul(x, P), x_T)
cont_out = unflatten(V)
cont_out = cont_out.detach().numpy()

# Plot the vector field
cp = ax.contourf(X, Y, cont_out[:,:,0])
fig.colorbar(cp)
plt.grid(True)
plt.show()

# %%
fig, ax = plt.subplots()
# Define grid for plotting
len_sample = [256, 256]
x = np.linspace(-1, 1, len_sample[0])
y = np.linspace(-1, 1, len_sample[1])
X, Y = np.meshgrid(x, y)

# Convert X and Y to torch tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
Y_tensor = torch.tensor(Y, dtype=torch.float32)

# Concatenate X and Y to create input data tensor
input_data = torch.stack((X_tensor, Y_tensor), dim=-1).reshape(-1, 2)
unflatten = torch.nn.Unflatten(0, len_sample)

# Vector Field
with torch.no_grad():
    F = model_f(input_data)
    vect_out = unflatten(F)
    vect_out = vect_out.detach().numpy()
    U = vect_out[:,:, 0]
    V = vect_out[:,:,1]
ax.streamplot(X, Y, U, V, density=1.4, linewidth=None, color='b')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Vector Field for Neural Network Dynamical System')

# Lyapunov Function
with torch.no_grad():
    V = model_v(input_data)
    cont_out = unflatten(V)
    cont_out = cont_out.detach().numpy()
# Plot the vector field
cp = ax.contourf(X, Y, cont_out[:,:,0])
fig.colorbar(cp)
plt.grid(True)
plt.show()

# %% [markdown]
# ## Plot the Training Trajectories and the Output Trajectory taken by the model

# %%
# Plotting trajectories
t = np.linspace(0, 10, 1000)

for i in range(num_trajectories):
    x = np.zeros((len(t), 2))
    x_dot = np.zeros((len(t), 2))
    x[0] = x0_values[i]
    for j in range(1, len(t)):
        x_dot[j-1] = np.dot(A, x[j-1])
        x[j] = x[j-1] + x_dot[j-1] * (t[j] - t[j-1])
    X_data[i*len(t):(i+1)*len(t),:] = x
    X_dot_data[i*len(t):(i+1)*len(t),:] = x_dot
    plt.plot(x[:, 0], x[:, 1],'b')

# Plotting the final trajectory
x = torch.zeros((len(t), 2))
x[0] = torch.tensor([0.8,0.8], dtype=torch.float32)
for j in range(1, len(t)):
    x[j] = x[j-1] + model_f(x[j-1]) * (t[j] - t[j-1])
x = x.detach().numpy()
plt.plot(x[:, 0], x[:, 1],'r')

# Plotting the origin
#plt.plot(0, 0, 'ro')
#plt.text(0.1, 0.1, 'Origin (0, 0)', fontsize=10)

plt.xlabel('x')
plt.ylabel('y')
plt.title('100 Trajectories of the Linear Dynamical System')
plt.grid(True)
plt.axis('equal')
plt.show()
